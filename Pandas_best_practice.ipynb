# %%
multiline_string = """
b"""

# %%
multiline_string
# Out:
# '\nb'

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  90.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[0, 'age'] = 40

# %%
titanic.iloc[0, 3] = 60

# %%
titanic.loc[titanic['age'] == 60, 'age'] = 90

# %%
titanic.loc[titanic['age'] < 1].index
# Out:
# Int64Index([78, 305, 469, 644, 755, 803, 831], dtype='int64')

# %%
titanic.loc[titanic['age'] < 1, ['sex','age', 'fare']]
# Out:
#         sex   age      fare
# 78     male  0.83   29.0000
# 305    male  0.92  151.5500
# 469  female  0.75   19.2583
# 644  female  0.75   19.2583
# 755    male  0.67   14.5000
# 803    male  0.42    8.5167
# 831    male  0.83   18.7500

# %%
titanic.loc[titanic['age'] < 1, ['age']] = 1

# %%
babies = titanic.loc[titanic['age'] == 1, ['age']].index

# %%
titanic.loc[babies, :]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 164         0       3    male  1.0      4      1   39.6875        S  NaN
# 172         1       3  female  1.0      1      1   11.1333        S  NaN
# 183         1       2    male  1.0      2      1   39.0000        S    F
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 381         1       3  female  1.0      0      2   15.7417        C  NaN
# 386         0       3    male  1.0      5      2   46.9000        S  NaN
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 788         1       3    male  1.0      1      2   20.5750        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# ...

# %%
titanic.loc[0, ['survived','sex','age']]
# Out:
# survived         1
# sex              1
# age         female
# Name: 0, dtype: object

# %%
titanic.loc[0, ['survived','sex','age']] = [1,1,'female']

# %%
titanic
# Out:
#      survived  pclass     sex     age  sibsp  parch     fare embarked deck
# 0           1       3       1  female      1      0   7.2500        S  NaN
# 1           1       1  female    38.0      1      0  71.2833        C    C
# 2           1       3  female    26.0      0      0   7.9250        S  NaN
# 3           1       1  female    35.0      1      0  53.1000        S    C
# 4           0       3    male    35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...     ...    ...    ...      ...      ...  ...
# 886         0       2    male    27.0      0      0  13.0000        S  NaN
# 887         1       1  female    19.0      0      0  30.0000        S    B
# 888         0       3  female     NaN      1      2  23.4500        S  NaN
# 889         1       1    male    26.0      0      0  30.0000        C    C
# 890         0       3    male    32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.dtypes
# Out:
# survived    object
# pclass       int64
# sex         object
# age         object
# sibsp       object
# parch       object
# fare        object
# embarked    object
# deck        object
# dtype: object

# %%
titanic.replace(0, 'Zero', inplace=True)

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
high_eff = cars.loc[cars.mpg > 40].copy()

# %%
high_eff.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244   40          4          90.0        48.0    1985          21.5
# 309   40          4          98.0        76.0    2144          14.7
# 322   40          4          86.0        65.0    2110          17.9
# 324   40          4          85.0        65.0    2110          19.2
# 325   40          4          90.0        48.0    2085          21.7
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# 324          80   japan               datsun 210
# 325          80  europe     vw rabbit c (diesel)

# %%
high_eff.mpg = 40

# %%
cars.loc[cars.mpg > 40, 'mpg'].max()
# Out:
# 46.6

# %%
cars.loc[cars.mpg > 40].mpg = 40
# Out:
# /trials/lab/python/anaconda3-4.10.1/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
cars.loc[cars.mpg > 40, 'mpg'] = 40

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by='age', ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by=['pclass','sex','age'], ascending=True, inplace=True)

# %%
titanic.tail()
# Out:
#      survived  pclass   sex  age  sibsp  parch     fare embarked deck
# 837         0       3  male  NaN      0      0   8.0500        S  NaN
# 846         0       3  male  NaN      8      2  69.5500        S  NaN
# 859         0       3  male  NaN      0      0   7.2292        C  NaN
# 868         0       3  male  NaN      0      0   9.5000        S  NaN
# 878         0       3  male  NaN      0      0   7.8958        S  NaN

# %%
titanic.sort_values(by=['pclass','sex','age'], ascending=[True, True, False], inplace=True)

# %%
dict1 = {0: 33.422, 1: 39.2308, 2: 30.132}
dict2 = {0: 42.2422, 1: 43.342, 2: 42.424}
dict3 = {0: 13.422, 1: 9.2308, 2: 20.132}
dicts = []
dicts.append(dict1)
dicts.append(dict2)
dicts.append(dict3)

# %%
dicts
# Out:
# [{0: 33.422, 1: 39.2308, 2: 30.132},
#  {0: 42.2422, 1: 43.342, 2: 42.424},
#  {0: 13.422, 1: 9.2308, 2: 20.132}]

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.count(axis=0)
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
titanic.count(axis='index')
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
titanic.count(axis='columns')
# Out:
# 0      8
# 1      9
# 2      8
# 3      9
# 4      8
#       ..
# 886    8
# 887    9
# 888    7
# 889    9
# 890    8
# Length: 891, dtype: int64

# %%
titanic.mean(axis=0, numeric_only=None)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.mean(axis=0, numeric_only=True)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.sum(axis=0)
# Out:
# survived                                                  342
# pclass                                                   2057
# sex         malefemalefemalefemalemalemalemalemalefemalefe...
# age                                                  21205.17
# sibsp                                                     466
# parch                                                     340
# fare                                               28693.9493
# dtype: object

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.fare.cumsum(axis=0)
# Out:
# 0          7.2500
# 1         78.5333
# 2         86.4583
# 3        139.5583
# 4        147.6083
#           ...
# 886    28602.7493
# 887    28632.7493
# 888    28656.1993
# 889    28686.1993
# 890    28693.9493
# Name: fare, Length: 891, dtype: float64

# %%
titanic.corr().plot()
# Out:
# <AxesSubplot:>

# %%
titanic.survived.corr(titanic.pclass)
# Out:
# -0.33848103596101475

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.agg("mean")
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.agg(["mean","std"])
# Out:
#       survived    pclass        age     sibsp     parch       fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594  32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057  49.693429

# %%
titanic.agg(["mean","std","min","max","median"])
# Out:
#         survived    pclass     sex        age     sibsp     parch        fare
# mean    0.383838  2.308642     NaN  29.699118  0.523008  0.381594   32.204208
# std     0.486592  0.836071     NaN  14.526497  1.102743  0.806057   49.693429
# min     0.000000  1.000000  female   0.420000  0.000000  0.000000    0.000000
# max     1.000000  3.000000    male  80.000000  8.000000  6.000000  512.329200
# median  0.000000  3.000000     NaN  28.000000  0.000000  0.000000   14.454200

# %%
titanic.agg({"survived":"mean", "age":["median","min","max"]})
# Out:
#         survived    age
# mean    0.383838    NaN
# median       NaN  28.00
# min          NaN   0.42
# max          NaN  80.00

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.sort_values(by='mpg', ascending=False, inplace=True)

# %%
cars.loc[:5,:]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# ..    ...        ...           ...         ...     ...           ...
# 154  15.0          6         250.0        72.0    3432          21.0
# 72   15.0          8         304.0       150.0    3892          12.5
# 64   15.0          8         318.0       150.0    4135          13.5
# 224  15.0          8         302.0       130.0    4295          14.9
# 5    15.0          8         429.0       198.0    4341          10.0
#
#      model_year  origin                     name
# 322          80   japan                mazda glc
# ...

# %%
cars.sort_index(ascending=True, inplace=True)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars["hp_rank"] = cars.horsepower.rank(method='min', ascending=False)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  hp_rank
# 0          70    usa  chevrolet chevelle malibu     92.0
# 1          70    usa          buick skylark 320     34.0
# 2          70    usa         plymouth satellite     46.0
# 3          70    usa              amc rebel sst     46.0
# 4          70    usa                ford torino     78.0

# %%
cars.sort_values(by='horsepower', ascending=True)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19   26.0          4          97.0        46.0    1835          20.5
# 102  26.0          4          97.0        46.0    1950          21.0
# 326  43.4          4          90.0        48.0    2335          23.7
# 325  44.3          4          90.0        48.0    2085          21.7
# 244  43.1          4          90.0        48.0    1985          21.5
# ..    ...        ...           ...         ...     ...           ...
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                     name  hp_rank
# 19           70  europe     vw 1131 deluxe sedan    391.0
# ...

# %%
cars.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            300
# hp_rank          93
# dtype: int64

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year     hp_rank
# count    398.000000  398.000000  392.000000
# mean      15.568090   76.010050  192.239796
# std        2.757689    3.697627  113.441056
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000   98.500000
# 50%       15.500000   76.000000  196.500000
# ...

# %%
cars.nlargest(n=10, columns='weight')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 42   12.0          8         383.0       180.0    4955          11.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 104  12.0          8         400.0       167.0    4906          12.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 94   13.0          8         440.0       215.0    4735          11.0
# 28    9.0          8         304.0       193.0    4732          18.5
# 137  13.0          8         350.0       150.0    4699          14.5
#
#      model_year origin                          name  hp_rank
# 44           71    usa           pontiac safari (sw)     23.0
# 103          73    usa              chevrolet impala     46.0
# ...

# %%
cars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# hp_rank       0.836399  -0.827170     -0.855328   -0.928239 -0.865003
#
#               acceleration  model_year   hp_rank
# mpg               0.420289    0.579267  0.836399
# cylinders        -0.505419   -0.348746 -0.827170
# displacement     -0.543684   -0.370164 -0.855328
# horsepower       -0.689196   -0.416361 -0.928239
# weight           -0.417457   -0.306564 -0.865003
# ...

# %%
import pandas as pd

# %%
sales = pd.read_csv("sales.csv", index_col = 0)

# %%
sales.head()
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     4 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 192.0+ bytes

# %%
sales.min(axis=0)
# Out:
# Mon    17.0
# Tue     9.0
# Wed    15.0
# Thu     8.0
# Fri     7.0
# dtype: float64

# %%
sales.min(axis=1)
# Out:
# Steven    15.0
# Mike       9.0
# Andi       8.0
# Paul       7.0
# dtype: float64

# %%
def range(series):
    return series.max() - series.min()

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.apply(range, axis=0)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
sales.apply(lambda x: x.max() - x.min() , axis=0)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
sales.apply(lambda x: x.max() - x.min() , axis=1)
# Out:
# Steven    19.0
# Mike      78.0
# Andi      46.0
# Paul      80.0
# dtype: float64

# %%
import pandas as pd
summer = pd.read_csv("summer.csv")

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.Athlete.apply(lambda x: x.split(",")[0])
# Out:
# 0             HAJOS
# 1        HERSCHMANN
# 2            DRIVAS
# 3         MALOKINIS
# 4          CHASAPIS
#             ...
# 31160    JANIKOWSKI
# 31161        REZAEI
# 31162        TOTROV
# 31163    ALEKSANYAN
# 31164       LIDBERG
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete.map(lambda x: x.split(",")[0])
# Out:
# 0             HAJOS
# 1        HERSCHMANN
# 2            DRIVAS
# 3         MALOKINIS
# 4          CHASAPIS
#             ...
# 31160    JANIKOWSKI
# 31161        REZAEI
# 31162        TOTROV
# 31163    ALEKSANYAN
# 31164       LIDBERG
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.iloc[:,1:3].apply(lambda x: x[0:5], axis=0)
# Out:
#      City     Sport
# 0  Athens  Aquatics
# 1  Athens  Aquatics
# 2  Athens  Aquatics
# 3  Athens  Aquatics
# 4  Athens  Aquatics

# %%
summer.iloc[:,1:5].apply(lambda x: x[0:5], axis=1)
# Out:
#          City      Sport           Discipline                    Athlete
# 0      Athens   Aquatics             Swimming              HAJOS, Alfred
# 1      Athens   Aquatics             Swimming           HERSCHMANN, Otto
# 2      Athens   Aquatics             Swimming          DRIVAS, Dimitrios
# 3      Athens   Aquatics             Swimming         MALOKINIS, Ioannis
# 4      Athens   Aquatics             Swimming         CHASAPIS, Spiridon
# ...       ...        ...                  ...                        ...
# 31160  London  Wrestling  Wrestling Freestyle         JANIKOWSKI, Damian
# 31161  London  Wrestling  Wrestling Freestyle  REZAEI, Ghasem Gholamreza
# 31162  London  Wrestling  Wrestling Freestyle             TOTROV, Rustam
# 31163  London  Wrestling  Wrestling Freestyle          ALEKSANYAN, Artur
# 31164  London  Wrestling  Wrestling Freestyle             LIDBERG, Jimmy
#
# [31165 rows x 4 columns]

# %%
summer.iloc[:,1:5].applymap(lambda x: x[0:3])
# Out:
#       City Sport Discipline Athlete
# 0      Ath   Aqu        Swi     HAJ
# 1      Ath   Aqu        Swi     HER
# 2      Ath   Aqu        Swi     DRI
# 3      Ath   Aqu        Swi     MAL
# 4      Ath   Aqu        Swi     CHA
# ...    ...   ...        ...     ...
# 31160  Lon   Wre        Wre     JAN
# 31161  Lon   Wre        Wre     REZ
# 31162  Lon   Wre        Wre     TOT
# 31163  Lon   Wre        Wre     ALE
# 31164  Lon   Wre        Wre     LID
#
# [31165 rows x 4 columns]

# %%
summer.iloc[:,1:3].apply(lambda x: x[0:3])
# Out:
#      City     Sport
# 0  Athens  Aquatics
# 1  Athens  Aquatics
# 2  Athens  Aquatics

# %%
summer.iloc[:,1:5].apply(lambda x: x[0:2], axis=1)
# Out:
#          City      Sport
# 0      Athens   Aquatics
# 1      Athens   Aquatics
# 2      Athens   Aquatics
# 3      Athens   Aquatics
# 4      Athens   Aquatics
# ...       ...        ...
# 31160  London  Wrestling
# 31161  London  Wrestling
# 31162  London  Wrestling
# 31163  London  Wrestling
# 31164  London  Wrestling
#
# [31165 rows x 2 columns]

# %%
summer.iloc[:,1:5].apply(lambda x: x[0:2], axis=0)
# Out:
#      City     Sport Discipline           Athlete
# 0  Athens  Aquatics   Swimming     HAJOS, Alfred
# 1  Athens  Aquatics   Swimming  HERSCHMANN, Otto

# %%
summer.iloc[:,1:5].applymap(lambda x: x[0:2])
# Out:
#       City Sport Discipline Athlete
# 0       At    Aq         Sw      HA
# 1       At    Aq         Sw      HE
# 2       At    Aq         Sw      DR
# 3       At    Aq         Sw      MA
# 4       At    Aq         Sw      CH
# ...    ...   ...        ...     ...
# 31160   Lo    Wr         Wr      JA
# 31161   Lo    Wr         Wr      RE
# 31162   Lo    Wr         Wr      TO
# 31163   Lo    Wr         Wr      AL
# 31164   Lo    Wr         Wr      LI
#
# [31165 rows x 4 columns]

# %%
summer.Athlete.apply(lambda x:x[0:2])
# Out:
# 0        HA
# 1        HE
# 2        DR
# 3        MA
# 4        CH
#          ..
# 31160    JA
# 31161    RE
# 31162    TO
# 31163    AL
# 31164    LI
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete.map(lambda x:x[1:2])
# Out:
# 0        A
# 1        E
# 2        R
# 3        A
# 4        H
#         ..
# 31160    A
# 31161    E
# 31162    O
# 31163    L
# 31164    I
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.iloc[:,1:3].applymap(lambda x : x[0])
# Out:
#       City Sport
# 0        A     A
# 1        A     A
# 2        A     A
# 3        A     A
# 4        A     A
# ...    ...   ...
# 31160    L     W
# 31161    L     W
# 31162    L     W
# 31163    L     W
# 31164    L     W
#
# [31165 rows x 2 columns]

# %%
type(summer.select_dtypes(include=['object']))
# Out:
# pandas.core.frame.DataFrame

# %%
summer.iloc[:,1:3].select_dtypes(include=['object']).applymap(lambda x : x[0])
# Out:
#       City Sport
# 0        A     A
# 1        A     A
# 2        A     A
# 3        A     A
# 4        A     A
# ...    ...   ...
# 31160    L     W
# 31161    L     W
# 31162    L     W
# 31163    L     W
# 31164    L     W
#
# [31165 rows x 2 columns]

# %%
summer_obj = summer.loc[:, summer.dtypes == 'object']

# %%
type(summer_obj.iloc[:, 4:5])
# Out:
# pandas.core.frame.DataFrame

# %%
summer_obj.iloc[:, 3:4].applymap(lambda x : x[0])
# Out:
#       Athlete
# 0           H
# 1           H
# 2           D
# 3           M
# 4           C
# ...       ...
# 31160       J
# 31161       R
# 31162       T
# 31163       A
# 31164       L
#
# [31165 rows x 1 columns]

# %%
summer_obj.iloc[1:2, 4:5]
# Out:
#   Country
# 1     AUT

# %%
summer_obj.dtypes
# Out:
# City          object
# Sport         object
# Discipline    object
# Athlete       object
# Country       object
# Gender        object
# Event         object
# Medal         object
# dtype: object

# %%
sales = pd.read_csv("sales.csv", index_col = 0)

# %%
sales.head(2)
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12

# %%
sales.applymap(lambda x : 0.4 * x -5)
# Out:
#          Mon   Tue   Wed   Thu  Fri
# Steven   8.6   5.8   1.0   NaN  8.2
# Mike    13.0  -1.4  24.6  29.8 -0.2
# Andi     1.8   8.2  16.6  -1.8  6.6
# Paul    29.8  21.8   5.8  13.0 -2.2

# %%
sales*.4 -5
# Out:
#          Mon   Tue   Wed   Thu  Fri
# Steven   8.6   5.8   1.0   NaN  8.2
# Mike    13.0  -1.4  24.6  29.8 -0.2
# Andi     1.8   8.2  16.6  -1.8  6.6
# Paul    29.8  21.8   5.8  13.0 -2.2

# %%
titanic = pd.read_csv("titanic.csv")
titanic_subset = titanic.iloc[:50, :]

# %%
titanic_subset.set_index(["pclass","sex"], inplace=True)

# %%
titanic_subset.head(3)
# Out:
#                survived   age  sibsp  parch     fare embarked deck
# pclass sex
# 3      male           0  22.0      1      0   7.2500        S  NaN
# 1      female         1  38.0      1      0  71.2833        C    C
# 3      female         1  26.0      0      0   7.9250        S  NaN

# %%
titanic_subset.sort_index(ascending=[False, True])
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 3      female         1  26.0      0      0    7.9250        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
#        female         1   4.0      1      1   16.7000        S    G
#        female         0  14.0      0      0    7.8542        S  NaN
#        female         0  31.0      1      0   18.0000        S  NaN
#        female         1   NaN      0      0    7.2250        C  NaN
#        female         1  15.0      0      0    8.0292        Q  NaN
#        female         0   8.0      3      1   21.0750        S  NaN
#        female         1  38.0      1      5   31.3875        S  NaN
#        female         1   NaN      0      0    7.8792        Q  NaN
#        female         1   NaN      0      0    7.7500        Q  NaN
#        female         0  18.0      2      0   18.0000        S  NaN
#        female         1  14.0      1      0   11.2417        C  NaN
# ...

# %%
titanic_subset.swaplevel()
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# sex    pclass
# male   3              0  22.0      1      0    7.2500        S  NaN
# female 1              1  38.0      1      0   71.2833        C    C
#        3              1  26.0      0      0    7.9250        S  NaN
#        1              1  35.0      1      0   53.1000        S    C
# male   3              0  35.0      0      0    8.0500        S  NaN
#        3              0   NaN      0      0    8.4583        Q  NaN
#        1              0  54.0      0      0   51.8625        S    E
#        3              0   2.0      3      1   21.0750        S  NaN
# female 3              1  27.0      0      2   11.1333        S  NaN
#        2              1  14.0      1      0   30.0708        C  NaN
#        3              1   4.0      1      1   16.7000        S    G
#        1              1  58.0      0      0   26.5500        S    C
# male   3              0  20.0      0      0    8.0500        S  NaN
# ...

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic = titanic.set_index(["pclass","sex"]).sort_index(ascending=True)

# %%
titanic.head()
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D

# %%
titanic.loc[1]
# Out:
#         survived   age  sibsp  parch      fare embarked deck
# sex
# female         1  38.0      1      0   71.2833        C    C
# female         1  35.0      1      0   53.1000        S    C
# female         1  58.0      0      0   26.5500        S    C
# female         1   NaN      1      0  146.5208        C    B
# female         1  49.0      1      0   76.7292        C    D
# ...          ...   ...    ...    ...       ...      ...  ...
# male           1   NaN      0      0   29.7000        C    C
# male           1  51.0      0      0   26.5500        S    E
# male           0  31.0      0      0   50.4958        S    A
# male           0  33.0      0      0    5.0000        S    B
# male           1  26.0      0      0   30.0000        C    C
#
# [216 rows x 7 columns]

# %%
titanic.loc[[1,2]]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 2      male           0  28.0      0      1   33.0000        S  NaN
#        male           0  21.0      1      0   11.5000        S  NaN
#        male           0  24.0      0      0   13.0000        S  NaN
#        male           0  28.0      0      0   10.5000        S  NaN
#        male           0  27.0      0      0   13.0000        S  NaN
#
# [400 rows x 7 columns]

# %%
titanic.loc[:2]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 2      male           0  28.0      0      1   33.0000        S  NaN
#        male           0  21.0      1      0   11.5000        S  NaN
#        male           0  24.0      0      0   13.0000        S  NaN
#        male           0  28.0      0      0   10.5000        S  NaN
#        male           0  27.0      0      0   13.0000        S  NaN
#
# [400 rows x 7 columns]

# %%
titanic.loc[1, 'female']
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
#        female         1  45.0      1      1  164.8667        S  NaN
#        female         1  48.0      0      0   25.9292        S    D
#        female         1  47.0      1      1   52.5542        S    D
#        female         1  56.0      0      1   83.1583        C    C
#        female         1  19.0      0      0   30.0000        S    B
#
# [94 rows x 7 columns]

# %%
titanic.loc[(1, 'female'), ['age','fare']]
# Out:
#                 age      fare
# pclass sex
# 1      female  38.0   71.2833
#        female  35.0   53.1000
#        female  58.0   26.5500
#        female   NaN  146.5208
#        female  49.0   76.7292
# ...             ...       ...
#        female  45.0  164.8667
#        female  48.0   25.9292
#        female  47.0   52.5542
#        female  56.0   83.1583
#        female  19.0   30.0000
#
# [94 rows x 2 columns]

# %%
titanic.loc[([1,2], 'female'), ['age','fare']]
# Out:
#                 age      fare
# pclass sex
# 1      female  38.0   71.2833
#        female  35.0   53.1000
#        female  58.0   26.5500
#        female   NaN  146.5208
#        female  49.0   76.7292
# ...             ...       ...
# 2      female  44.0   26.0000
#        female  42.0   13.0000
#        female  27.0   13.8583
#        female  28.0   24.0000
#        female  25.0   26.0000
#
# [170 rows x 2 columns]

# %%
titanic.loc[([1,2], 'female'), :]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 2      female         0  44.0      1      0   26.0000        S  NaN
#        female         1  42.0      0      0   13.0000        S  NaN
#        female         1  27.0      1      0   13.8583        C  NaN
#        female         1  28.0      1      0   24.0000        C  NaN
#        female         1  25.0      0      1   26.0000        S  NaN
#
# [170 rows x 7 columns]

# %%
titanic.loc[(slice(None), "female"), :]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      female         0   NaN      8      2   69.5500        S  NaN
#        female         1  15.0      0      0    7.2250        C  NaN
#        female         0  22.0      0      0   10.5167        S  NaN
#        female         0  39.0      0      5   29.1250        Q  NaN
#        female         0   NaN      1      2   23.4500        S  NaN
#
# [314 rows x 7 columns]

# %%
titanic.loc[slice(None), :]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0  19.0      0      0    7.8958        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#        male           0  33.0      0      0    7.8958        S  NaN
#        male           0  25.0      0      0    7.0500        S  NaN
#        male           0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
titanic.loc[(slice(None), slice('male')), :]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0  19.0      0      0    7.8958        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#        male           0  33.0      0      0    7.8958        S  NaN
#        male           0  25.0      0      0    7.0500        S  NaN
#        male           0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
titanic.loc[(slice(None), slice('female')), :]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      female         0   NaN      8      2   69.5500        S  NaN
#        female         1  15.0      0      0    7.2250        C  NaN
#        female         0  22.0      0      0   10.5167        S  NaN
#        female         0  39.0      0      5   29.1250        Q  NaN
#        female         0   NaN      1      2   23.4500        S  NaN
#
# [314 rows x 7 columns]

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
type('Hello World')
# Out:
# str

# %%
hello = "Hello World"

# %%
len(hello)
# Out:
# 11

# %%
hello.lower()
# Out:
# 'hello world'

# %%
hello.title()
# Out:
# 'Hello World'

# %%
hello.split(" ")
# Out:
# ['Hello', 'World']

# %%
hello.replace("Hello", "Hi")
# Out:
# 'Hi World'

# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.dtypes
# Out:
# Year           int64
# City          object
# Sport         object
# Discipline    object
# Athlete       object
# Country       object
# Gender        object
# Event         object
# Medal         object
# dtype: object

# %%
names = summer.loc[:9, 'Athlete'].copy()

# %%
names.str.lower()
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %%
summer.Event.str.split(" ", n=1, expand=True)
# Out:
#           0                      1
# 0      100M              Freestyle
# 1      100M              Freestyle
# 2      100M  Freestyle For Sailors
# 3      100M  Freestyle For Sailors
# 4      100M  Freestyle For Sailors
# ...     ...                    ...
# 31160    Wg                  84 KG
# 31161    Wg                  96 KG
# 31162    Wg                  96 KG
# 31163    Wg                  96 KG
# 31164    Wg                  96 KG
#
# [31165 rows x 2 columns]

# %%
summer.Event.str.contains('100M')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Event, Length: 31165, dtype: bool

# %%
summer.loc[summer.Event.str.contains('100M'),:]
# Out:
#        Year    City      Sport Discipline               Athlete Country  \
# 0      1896  Athens   Aquatics   Swimming         HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics   Swimming      HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics   Swimming     DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics   Swimming    MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics   Swimming    CHASAPIS, Spiridon     GRE
# ...     ...     ...        ...        ...                   ...     ...
# 29660  2012  London  Athletics  Athletics       STEWART, Kerron     JAM
# 29661  2012  London  Athletics  Athletics  BRYZGINA, Yelyzaveta     UKR
# 29662  2012  London  Athletics  Athletics          POVH, Olesya     UKR
# 29663  2012  London  Athletics  Athletics       RYEMYEN, Mariya     UKR
# 29664  2012  London  Athletics  Athletics        STUY, Hrystyna     UKR
#
#       Gender                       Event   Medal
# 0        Men              100M Freestyle    Gold
# ...

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.iloc[:, :-2].apply(lambda x: x.max() - x.min(), axis=0)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# model_year        12.0
# dtype: float64

# %%
cars.iloc[:, :-2].applymap(lambda x: x * 10)
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    180.0         80        3070.0      1300.0   35040         120.0
# 1    150.0         80        3500.0      1650.0   36930         115.0
# 2    180.0         80        3180.0      1500.0   34360         110.0
# 3    160.0         80        3040.0      1500.0   34330         120.0
# 4    170.0         80        3020.0      1400.0   34490         105.0
# ..     ...        ...           ...         ...     ...           ...
# 393  270.0         40        1400.0       860.0   27900         156.0
# 394  440.0         40         970.0       520.0   21300         246.0
# 395  320.0         40        1350.0       840.0   22950         116.0
# 396  280.0         40        1200.0       790.0   26250         186.0
# 397  310.0         40        1190.0       820.0   27200         194.0
#
#      model_year
# 0           700
# 1           700
# 2           700
# 3           700
# 4           700
# ..          ...
# ...

# %%
cars.set_index(["model_year","origin"], inplace=True)

# %%
cars.loc[75]
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# usa     19.0          6         225.0        95.0    3264          16.0
# usa     18.0          6         250.0       105.0    3459          16.0
# usa     15.0          6         250.0        72.0    3432          21.0
# usa     15.0          6         250.0        72.0    3158          19.5
# usa     16.0          8         400.0       170.0    4668          11.5
# usa     15.0          8         350.0       145.0    4440          14.0
# usa     16.0          8         318.0       150.0    4498          14.5
# usa     14.0          8         351.0       148.0    4657          13.5
# usa     17.0          6         231.0       110.0    3907          21.0
# usa     16.0          6         250.0       105.0    3897          18.5
# usa     15.0          6         258.0       110.0    3730          19.0
# usa     18.0          6         225.0        95.0    3785          19.0
# ...

# %%
cars.loc[([76], "usa"), :]
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 76         usa     25.0          4         140.0        92.0    2572
#            usa     26.0          4          98.0        79.0    2255
#            usa     17.5          8         305.0       140.0    4215
#            usa     16.0          8         318.0       150.0    4190
#            usa     15.5          8         304.0       120.0    3962
#            usa     14.5          8         351.0       152.0    4215
#            usa     22.0          6         225.0       100.0    3233
#            usa     22.0          6         250.0       105.0    3353
#            usa     24.0          6         200.0        81.0    3012
#            usa     22.5          6         232.0        90.0    3085
#            usa     29.0          4          85.0        52.0    2035
#            usa     24.5          4          98.0        60.0    2164
# ...

# %%
cars.loc[([75, 76], 'japan'), ['mpg', 'name']]
# Out:
#                     mpg              name
# model_year origin
# 75         japan   29.0    toyota corolla
#            japan   24.0     toyota corona
#            japan   24.0        datsun 710
#            japan   33.0  honda civic cvcc
# 76         japan   33.0       honda civic
#            japan   32.0      datsun b-210
#            japan   28.0    toyota corolla
#            japan   19.0    toyota mark ii

# %%
cars.reset_index(inplace=True)

# %%
cars.head()
# Out:
#    model_year origin   mpg  cylinders  displacement  horsepower  weight  \
# 0          70    usa  18.0          8         307.0       130.0    3504
# 1          70    usa  15.0          8         350.0       165.0    3693
# 2          70    usa  18.0          8         318.0       150.0    3436
# 3          70    usa  16.0          8         304.0       150.0    3433
# 4          70    usa  17.0          8         302.0       140.0    3449
#
#    acceleration                       name
# 0          12.0  chevrolet chevelle malibu
# 1          11.5          buick skylark 320
# 2          11.0         plymouth satellite
# 3          12.0              amc rebel sst
# 4          10.5                ford torino

# %%
split = cars.name.str.split(pat= " ", n=1, expand=True)

# %%
type(split)
# Out:
# pandas.core.frame.DataFrame

# %%
split[0].value_counts()
# Out:
# ford             51
# chevrolet        47
# plymouth         31
# dodge            28
# amc              28
# toyota           26
# datsun           23
# vw               22
# buick            17
# pontiac          16
# honda            13
# mercury          12
# mazda            12
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# volvo             6
# chrysler          6
# renault           5
# subaru            4
# saab              4
# opel              4
# mercedes-benz     3
# bmw               2
# cadillac          2
# triumph           1
# ih                1
# nissan            1
# Name: 0, dtype: int64

# %%
split.value_counts()
# Out:
# 0       1
# ford    pinto              6
#         maverick           5
# toyota  corolla            5
# vw      rabbit             5
# amc     matador            5
#                           ..
# dodge   st. regis          1
# fiat    124 sport coupe    1
#         124 tc             1
#         124b               1
# vw      type 3             1
# Length: 299, dtype: int64

# %%
split.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       398 non-null    object
#  1   1       396 non-null    object
# dtypes: object(2)
# memory usage: 6.3+ KB

# %%
split.agg('sum', axis=1)
# Out:
# 0      chevroletchevelle malibu
# 1              buickskylark 320
# 2             plymouthsatellite
# 3                  amcrebel sst
# 4                    fordtorino
#                  ...
# 393              fordmustang gl
# 394                    vwpickup
# 395                dodgerampage
# 396                  fordranger
# 397               chevrolets-10
# Length: 396, dtype: object

# %%
cars.name.str.contains("ford").value_counts()
# Out:
# False    347
# True      51
# Name: name, dtype: int64

# %%
cars.name.str.contains("ford").sum()
# Out:
# 51

# %%
with open("titanic.csv") as f:
    text = f.readlines()

# %%
text
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
# ...

# %%
len(text)
# Out:
# 892

# %%
print("hello world!")
# Out:
# hello world!

# %%
import pandas as pd

# %%
pd.read_csv("titanic.csv", index_col="pclass")
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN
# ...          ...     ...   ...    ...    ...      ...      ...  ...
# 2              0    male  27.0      0      0  13.0000        S  NaN
# 1              1  female  19.0      0      0  30.0000        S    B
# 3              0  female   NaN      1      2  23.4500        S  NaN
# 1              1    male  26.0      0      0  30.0000        C    C
# 3              0    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %%
pd.read_csv("titanic.csv", header=0)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.read_csv("titanic.csv", header=0, names=["alive", "class", "gender", "age", "parch", "price", "emb", "deck"])
# Out:
#     alive   class  gender  age  parch    price emb deck
# 0       3    male    22.0    1      0   7.2500   S  NaN
# 1       1  female    38.0    1      0  71.2833   C    C
# 1       3  female    26.0    0      0   7.9250   S  NaN
# 1       1  female    35.0    1      0  53.1000   S    C
# 0       3    male    35.0    0      0   8.0500   S  NaN
# ..    ...     ...     ...  ...    ...      ...  ..  ...
# 0       2    male    27.0    0      0  13.0000   S  NaN
# 1       1  female    19.0    0      0  30.0000   S    B
# 0       3  female     NaN    1      2  23.4500   S  NaN
# 1       1    male    26.0    0      0  30.0000   C    C
# 0       3    male    32.0    0      0   7.7500   Q  NaN
#
# [891 rows x 8 columns]

# %%
titanic = pd.read_csv("titanic.csv", header=0, index_col = "pclass", usecols = ["sex","age","fare", "pclass"])

# %%
titanic.columns
# Out:
# Index(['sex', 'age', 'fare'], dtype='object')

# %%
titanic.head(2)
# Out:
#            sex   age     fare
# pclass
# 3         male  22.0   7.2500
# 1       female  38.0  71.2833

# %%
titanic.columns = ["gender", "age", "price"]
titanic.index.name = "class"
titanic.head()
# Out:
#        gender   age    price
# class
# 3        male  22.0   7.2500
# 1      female  38.0  71.2833
# 3      female  26.0   7.9250
# 1      female  35.0  53.1000
# 3        male  35.0   8.0500

# %%
import pandas as pd

# %%
pd.read_csv("titanic_raw.csv")
# Out:
#                                               This       is       the  \
# It   contains  all       passengers  that     were   aboard       the
# the  tragic    disaster  occured     in        the     year        19
# 0   0         3         male        22.0         1        0     $7.25
# 1   1         1         female      38.0         1        0  $71.2833
# 2   1         3         female      26.0         0        0    $7.925
# ...                                            ...      ...       ...
# 891 0         2         male        24.0         0        0     $10.5
# 892 0         3         male        34.0         1        1     $14.4
# 893 0         3         male        36.0         0        0   $7.8958
# End  of        the       Dataset                                  NaN
# Get  more      Datasets  on          Kaggle      .      com       NaN
#
#                                               Titanic  Dataset.
# ...

# %%
col_names = ["survived","class","gender","age","sipsp","parch","fare","enb","deck"]

# %%
titanic_raw = pd.read_csv("titanic_raw.csv", skiprows=3, skipfooter=2, engine='python',\
            header=None, names = col_names)

# %%
titanic_raw.to_csv("titanic_inp.csv", index=False)

# %%
pd.read_csv("titanic_inp.csv")
# Out:
#     survived  class  gender   age  sipsp  parch      fare enb deck
# 0          0      3    male  22.0      1      0     $7.25   S  NaN
# 1          1      1  female  38.0      1      0  $71.2833   C    C
# 2          1      3  female  26.0      0      0    $7.925   S  NaN
# 3          1      1  female  35.0      1      0     $53.1   S    C
# 4          0      3    male  35.0      0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...    ...    ...       ...  ..  ...
# 889        1      1    male  26.0      0      0     $30.0   C    C
# 890        0      3    male  32.0      0      0     $7.75   Q  NaN
# 891        0      2    male  24.0      0      0     $10.5   S  NaN
# 892        0      3    male  34.0      1      1     $14.4   S  NaN
# 893        0      3    male  36.0      0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %%
import pandas as pd

# %%
sales = pd.read_excel("sales.xls", index_col=0, header= 0, \
                     names = ["Name","Loc_City","Loc_Country","Revenue",\
                              "Add_Comp"])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, nan to Tom
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       6 non-null      object
#  1   2       6 non-null      object
#  2   3       6 non-null      object
#  3   4       6 non-null      object
# dtypes: object(4)
# memory usage: 240.0+ bytes

# %%
sales.head(2)
# Out:
#       Loc_City Loc_Country  Revenue  Add_Comp
# Name
# Mike  New York         USA       25       2.5
# Jim     Boston         USA       43       4.3

# %%
sales.index.name = "name"

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = "A:C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = "A, C:E")
# Out:
#        Country  Sales  Bonus
# Mike       USA     25   2.50
# Jim        USA     43   4.30
# Steven      UK     76   7.60
# Joe      Spain     12   1.80
# Tom     France     89  13.35

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = ":C")
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = "C:")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-ff874b173b88> in <module>
# ----> 1 pd.read_excel("sales.xls", index_col=0, header=0, usecols = "C:")
#
# /trials/lab/python/anaconda3-4.10.1/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /trials/lab/python/anaconda3-4.10.1/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = [0,3, 5])
# Out:
#         Sales
# Mike       25
# Jim        43
# Steven     76
# Joe        12
# Tom        89

# %%
pd.read_excel("sales.xls", index_col=0, header=0, usecols = ["City","Sales"])
# Out:
#           Sales
# City
# New York     25
# Boston       43
# London       76
# Madrid       12
# Paris        89

# %%
import pandas as pd

# %%
pd.read_excel("summer_raw.xls", index_col=0)
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25    2.5
# Jim       Boston     USA     43    4.3
# Steven    London      UK     76    7.6
# Joe       Madrid   Spain     12    1.8
# Tom        Paris  France     89   13.4

# %%
pd.read_excel("summer_raw.xls",sheet_name='sales', index_col=0)
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25    2.5
# Jim       Boston     USA     43    4.3
# Steven    London      UK     76    7.6
# Joe       Madrid   Spain     12    1.8
# Tom        Paris  France     89   13.4

# %%
pd.read_excel("summer_raw.xls",sheet_name='summer', index_col=1, skiprows=2)
# Out:
#      Unnamed: 0  Unnamed: 2  Year    City      Sport           Discipline  \
# NaN         NaN           0  1896  Athens   Aquatics             Swimming
# NaN         NaN           1  1896  Athens   Aquatics             Swimming
# NaN         NaN           2  1896  Athens   Aquatics             Swimming
# NaN         NaN           3  1896  Athens   Aquatics             Swimming
# NaN         NaN           4  1896  Athens   Aquatics             Swimming
# ..          ...         ...   ...     ...        ...                  ...
# NaN         NaN       31165  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31166  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31167  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31168  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31169  2012  London  Wrestling  Wrestling Freestyle
#
#                     Athlete Name Country Gender                       Event  \
# ...

# %%
pd.read_excel("summer_raw.xls",sheet_name='summer', index_col=1, skiprows=[0,1])
# Out:
#      Unnamed: 0  Unnamed: 2  Year    City      Sport           Discipline  \
# NaN         NaN           0  1896  Athens   Aquatics             Swimming
# NaN         NaN           1  1896  Athens   Aquatics             Swimming
# NaN         NaN           2  1896  Athens   Aquatics             Swimming
# NaN         NaN           3  1896  Athens   Aquatics             Swimming
# NaN         NaN           4  1896  Athens   Aquatics             Swimming
# ..          ...         ...   ...     ...        ...                  ...
# NaN         NaN       31165  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31166  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31167  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31168  2012  London  Wrestling  Wrestling Freestyle
# NaN         NaN       31169  2012  London  Wrestling  Wrestling Freestyle
#
#                     Athlete Name Country Gender                       Event  \
# ...

# %%
pd.read_excel("summer_raw.xls",sheet_name='summer',\
              index_col=0, skiprows=2, usecols="D:L")
# Out:
#         City      Sport           Discipline                 Athlete Name  \
# Year
# 1896  Athens   Aquatics             Swimming               HAJOS, Alfred
# 1896  Athens   Aquatics             Swimming            HERSCHMANN, Otto
# 1896  Athens   Aquatics             Swimming           DRIVAS, Dimitrios
# 1896  Athens   Aquatics             Swimming          Malokinis, Ioannis
# 1896  Athens   Aquatics             Swimming          Chasapis, Spiridon
# ...      ...        ...                  ...                          ...
# 2012  London  Wrestling  Wrestling Freestyle          JANIKOWSKI, Damian
# 2012  London  Wrestling  Wrestling Freestyle   REZAEI, Ghasem Gholamreza
# 2012  London  Wrestling  Wrestling Freestyle              TOTROV, Rustam
# 2012  London  Wrestling  Wrestling Freestyle           ALEKSANYAN, Artur
# 2012  London  Wrestling  Wrestling Freestyle              LIDBERG, Jimmy
#
#      Country Gender                       Event       Medal
# Year
# ...

# %%
summer = pd.read_excel("summer_raw.xls",sheet_name='summer',\
              index_col=0, skiprows=2, usecols="D:L")

# %%
summer.head()
# Out:
#         City     Sport Discipline          Athlete Name Country Gender  \
# Year
# 1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                            Event       Medal
# Year
# 1896              100M Freestyle  Gold Medal
# 1896              100M Freestyle      Silver
# 1896  100M Freestyle For Sailors      Bronze
# 1896  100M Freestyle For Sailors  Gold Medal
# 1896  100M Freestyle For Sailors      Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31170 entries, 1896 to 2012
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          31170 non-null  object
#  1   Sport         31170 non-null  object
#  2   Discipline    31170 non-null  object
#  3   Athlete Name  31170 non-null  object
#  4   Country       31166 non-null  object
#  5   Gender        31170 non-null  object
#  6   Event         31170 non-null  object
#  7   Medal         31170 non-null  object
# dtypes: object(8)
# memory usage: 2.1+ MB

# %%
summer.to_csv("summer_inp.csv", index=False)

# %%
summer.to_excel("summer_inp.xls")
# Out:
# <ipython-input-102-24747b597361>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   summer.to_excel("summer_inp.xls")

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
type(pd.read_html(url))
# Out:
# list

# %%
len(pd.read_html(url))
# Out:
# 6

# %%
medal_tally_1976 = pd.read_html(url)

# %%
medal_tally_1976[2]
# Out:
#                 Rank                  NOC  Gold  Silver  Bronze  Total
# 0                  1         Soviet Union    49      41      35    125
# 1                  2         East Germany    40      25      25     90
# 2                  3        United States    34      35      25     94
# 3                  4         West Germany    10      12      17     39
# 4                  5                Japan     9       6      10     25
# 5                  6               Poland     7       6      13     26
# 6                  7             Bulgaria     6       9       7     22
# 7                  8                 Cuba     6       4       3     13
# 8                  9              Romania     4       9      14     27
# 9                 10              Hungary     4       5      13     22
# 10                11              Finland     4       2       0      6
# 11                12               Sweden     4       1       0      5
# ...

# %%
type(medal_tally_1976[2])
# Out:
# pandas.core.frame.DataFrame

# %%
medal_tally_1976[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    42 non-null     object
#  1   NOC     42 non-null     object
#  2   Gold    42 non-null     int64
#  3   Silver  42 non-null     int64
#  4   Bronze  42 non-null     int64
#  5   Total   42 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.1+ KB

# %%
url2 = "https://en.wikipedia.org/wiki/1996_Summer_Olympics_medal_table"

# %%
medal_tally_1996 = pd.read_html(url2)

# %%
type(medal_tally_1996)
# Out:
# list

# %%
medal_tally_1996[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    80 non-null     object
#  1   Nation  80 non-null     object
#  2   Gold    80 non-null     int64
#  3   Silver  80 non-null     int64
#  4   Bronze  80 non-null     int64
#  5   Total   80 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 3.9+ KB

# %%
medal_tally_1996[2].loc[(medal_tally_1996[2]['Nation']=='India'), :]
# Out:
#    Rank Nation  Gold  Silver  Bronze  Total
# 70   71  India     0       0       1      1

# %%
medal_tally_1996[2]
# Out:
#                    Rank               Nation  Gold  Silver  Bronze  Total
# 0                     1       United States*    44      32      25    101
# 1                     2               Russia    26      21      16     63
# 2                     3              Germany    20      18      27     65
# 3                     4                China    16      22      12     50
# 4                     5               France    15       7      15     37
# ..                  ...                  ...   ...     ...     ...    ...
# 75                   71           Mozambique     0       0       1      1
# 76                   71          Puerto Rico     0       0       1      1
# 77                   71              Tunisia     0       0       1      1
# 78                   71               Uganda     0       0       1      1
# 79  Totals (79 nations)  Totals (79 nations)   271     273     298    842
#
# [80 rows x 6 columns]

# %%
medal_tally_1996[2].to_csv("medal_tally_1996", index=False)

# %%
medal_tally_1976[2].to_csv("medal_tally_1976", index=False)

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic_imp.csv")

# %%
titanic.describe()
# Out:
#             Class       SipSp       ParCh
# count  894.000000  894.000000  894.000000
# mean     2.309843    0.522371    0.381432
# std      0.835370    1.101283    0.805171
# min      1.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000
# 50%      3.000000    0.000000    0.000000
# 75%      3.000000    1.000000    0.000000
# max      3.000000    8.000000    6.000000

# %%
titanic.head(2)
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    object
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 63.0+ KB

# %%
titanic.describe()
# Out:
#             Class       SipSp       ParCh
# count  894.000000  894.000000  894.000000
# mean     2.309843    0.522371    0.381432
# std      0.835370    1.101283    0.805171
# min      1.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000
# 50%      3.000000    0.000000    0.000000
# 75%      3.000000    1.000000    0.000000
# max      3.000000    8.000000    6.000000

# %%
titanic.loc[:, ['Survived', 'Gender', 'Age', 'Fare', 'Emb',\
                'Deck']].describe()
# Out:
#        Survived Gender           Age   Fare  Emb Deck
# count       894    894           758    894  892  203
# unique        4      2            92    248    3    7
# top           0   male  Missing Data  $8.05    S    C
# freq        551    580            41     43  647   59

# %%
titanic.Survived.nunique()
# Out:
# 4

# %%
titanic.Survived.value_counts()
# Out:
# 0      551
# 1      341
# no       1
# yes      1
# Name: Survived, dtype: int64

# %%
titanic.Survived.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
titanic.Survived.replace(to_replace=['yes','no'], value=['1','0'], \
                        inplace=True)

# %%
import pandas as pd
titanic = pd.read_csv("titanic.csv")

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
summer = pd.read_csv('summer_imp.csv')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.rename(columns = {"Athlete Name":"Athlete_Name"}, inplace=True)

# %%
summer.head(2)
# Out:
#    Year    City     Sport Discipline        Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming      HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming   HERSCHMANN, Otto      AUT    Men
#
#             Event       Medal
# 0  100M Freestyle  Gold Medal
# 1  100M Freestyle      Silver

# %%
summer.Medal.value_counts()
# Out:
# Gold      10487
# Bronze    10372
# Silver    10311
# Name: Medal, dtype: int64

# %%
summer.Medal.replace(to_replace='Gold Medal', value="Gold", inplace=True)

# %%
summer.iloc[:, 1:].describe()
# Out:
#           City     Sport Discipline       Athlete_Name Country Gender  \
# count    31170     31170      31170              31170   31166  31170
# unique      22        43         67              22763     147      2
# top     London  Aquatics  Athletics   PHELPS, Michael      USA    Men
# freq      3567      4170       3639                 22    4586  22751
#
#            Event  Medal
# count      31170  31170
# unique       666      3
# top     Football   Gold
# freq        1497  10487

# %%
titanic = pd.read_csv('titanic_imp.csv')
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
titanic.Fare.str.replace("$","", regex=True)
# Out:
# 0         7.25
# 1      71.2833
# 2        7.925
# 3         53.1
# 4         8.05
#         ...
# 889       30.0
# 890       7.75
# 891       10.5
# 892       14.4
# 893     7.8958
# Name: Fare, Length: 894, dtype: object

# %%
summer.Athlete_Name = summer.Athlete_Name.str.title()

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        Hajos, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     Herschmann, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    Drivas, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.loc[summer.Athlete_Name.str.contains('Hajos, Alfred')]
# Out:
#    Year    City     Sport Discipline     Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
# 6  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.Athlete_Name = summer.Athlete_Name.str.strip()

# %%
summer.loc[summer.Athlete_Name == 'Hajos, Alfred']
# Out:
#    Year    City     Sport Discipline   Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.loc[summer.Athlete_Name == 'Phelps, Michael']
# Out:
#        Year     City     Sport Discipline     Athlete_Name Country Gender  \
# 25229  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25257  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25262  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25269  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25281  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25290  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25329  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25365  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27228  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27256  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27262  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27268  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# ...

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    object
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 63.0+ KB

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
# titanic.Fare.str.replace("$", "", regex=True)
titanic.Fare = titanic.Fare.str.replace("$","", regex=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    object
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 63.0+ KB

# %%
pd.to_numeric(titanic.Fare)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 889    30.0000
# 890     7.7500
# 891    10.5000
# 892    14.4000
# 893     7.8958
# Name: Fare, Length: 894, dtype: float64

# %%
titanic.head().Fare.astype("float")
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
titanic.head().Survived.astype("int")
# titanic.head(2)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
import pandas as pd

# %%
sales = pd.read_csv("sales.csv", index_col=0)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     4 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 192.0+ bytes

# %%
sales.head(5)
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked   deck
# 0       False   False  False  False  False  False  False     False   True
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False   True
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False   True
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False   True
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False   True
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False   True
#
# [891 rows x 9 columns]

# %%
titanic.isna().sum(axis=0)
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# deck        688
# dtype: int64

# %%
titanic.isna().any(axis=0)
# Out:
# survived    False
# pclass      False
# sex         False
# age          True
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic[titanic.isna().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [709 rows x 9 columns]

# %%
titanic[titanic.age.isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked deck
# 5           0       3    male  NaN      0      0   8.4583        Q  NaN
# 17          1       2    male  NaN      0      0  13.0000        S  NaN
# 19          1       3  female  NaN      0      0   7.2250        C  NaN
# 26          0       3    male  NaN      0      0   7.2250        C  NaN
# 28          1       3  female  NaN      0      0   7.8792        Q  NaN
# ..        ...     ...     ...  ...    ...    ...      ...      ...  ...
# 859         0       3    male  NaN      0      0   7.2292        C  NaN
# 863         0       3  female  NaN      8      2  69.5500        S  NaN
# 868         0       3    male  NaN      0      0   9.5000        S  NaN
# 878         0       3    male  NaN      0      0   7.8958        S  NaN
# 888         0       3  female  NaN      1      2  23.4500        S  NaN
#
# [177 rows x 9 columns]

# %%
titanic.notna()
# Out:
#      survived  pclass   sex    age  sibsp  parch  fare  embarked   deck
# 0        True    True  True   True   True   True  True      True  False
# 1        True    True  True   True   True   True  True      True   True
# 2        True    True  True   True   True   True  True      True  False
# 3        True    True  True   True   True   True  True      True   True
# 4        True    True  True   True   True   True  True      True  False
# ..        ...     ...   ...    ...    ...    ...   ...       ...    ...
# 886      True    True  True   True   True   True  True      True  False
# 887      True    True  True   True   True   True  True      True   True
# 888      True    True  True  False   True   True  True      True  False
# 889      True    True  True   True   True   True  True      True   True
# 890      True    True  True   True   True   True  True      True  False
#
# [891 rows x 9 columns]

# %%
titanic.notna().any(axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Length: 891, dtype: bool

# %%
titanic[titanic.notna().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.age.notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
titanic.loc[titanic.age.notna(),:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [714 rows x 9 columns]

# %%
titanic.notna().sum(axis=0)
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
titanic.notna().all(axis=1)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Length: 891, dtype: bool

# %%
titanic[titanic.notna().all(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 10          1       3  female   4.0      1      1  16.7000        S    G
# 11          1       1  female  58.0      0      0  26.5500        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
#
# [182 rows x 9 columns]

# %%
titanic.age.value_counts(dropna=False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 0.42       1
# 34.50      1
# 66.00      1
# 14.50      1
# 0.92       1
# Name: age, Length: 89, dtype: int64

# %%
titanic[titanic.age == 'Missing Data']
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, deck]
# Index: []

# %%
titanic[titanic.notna().all(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 10          1       3  female   4.0      1      1  16.7000        S    G
# 11          1       1  female  58.0      0      0  26.5500        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
#
# [182 rows x 9 columns]

# %%
titanic.deck.value_counts(dropna = False)
# Out:
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: deck, dtype: int64

# %%
titanic[titanic.deck.isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [688 rows x 9 columns]

# %%
titanic.age.mean(skipna = True)
# Out:
# 29.69911764705882

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.dropna().shape
# Out:
# (182, 9)

# %%
titanic.dropna(axis=0, how='any').shape
# Out:
# (182, 9)

# %%
titanic.dropna(axis=1, how='any').shape
# Out:
# (891, 6)

# %%
titanic.dropna(axis=0, how='all').shape
# Out:
# (891, 9)

# %%
titanic.dropna(axis=1, how='all').shape
# Out:
# (891, 9)

# %%
import pandas as pd
titanic = pd.read_csv('titanic.csv')

# %%
mean = titanic.age.mean()

# %%
import numpy as np
titanic.age.fillna(mean, inplace=True)

# %%
titanic.age.value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 30.000000     25
#             ...
# 53.000000      1
# 55.500000      1
# 0.920000       1
# 24.500000      1
# 70.500000      1
# Name: age, Length: 89, dtype: int64

# %%
import pandas as pd
alphabet = pd.DataFrame(['a','b','c','c','d','e','f','g','g','g'], columns=['alphabet'])

# %%
alphabet
# Out:
#   alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        e
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.duplicated(keep = False)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
#   alphabet
# 2        c
# 3        c
# 7        g
# 8        g
# 9        g

# %%
alphabet[alphabet.duplicated(keep = 'first')]
# Out:
#   alphabet
# 3        c
# 8        g
# 9        g

# %%
alphabet[alphabet.duplicated(keep = 'last')]
# Out:
#   alphabet
# 2        c
# 7        g
# 8        g

# %%
titanic = pd.read_csv('titanic.csv', \
                      names=['Survived','Class','Gender','Age',\
                             'SipSP', 'ParCh','Fare','Emb', 'Deck'], skiprows=1)

# %%
titanic.head()
# Out:
#    Survived  Class  Gender   Age  SipSP  ParCh     Fare Emb Deck
# 0         0      3    male  22.0      1      0   7.2500   S  NaN
# 1         1      1  female  38.0      1      0  71.2833   C    C
# 2         1      3  female  26.0      0      0   7.9250   S  NaN
# 3         1      1  female  35.0      1      0  53.1000   S    C
# 4         0      3    male  35.0      0      0   8.0500   S  NaN

# %%
titanic.duplicated(keep='first').sum()
# Out:
# 107

# %%
titanic.duplicated(keep=False).sum()
# Out:
# 160

# %%
titanic.duplicated(keep='last').sum()
# Out:
# 107

# %%
titanic.duplicated(keep='last', subset=['Survived', 'Class',\
                                        'Gender','Age',\
                                        'Fare']).sum()
# Out:
# 123

# %%
titanic.loc[titanic.duplicated(keep='last', subset=['Survived', 'Class',\
                                        'Gender','Age',\
                                        'Fare'])]
# Out:
#      Survived  Class  Gender   Age  SipSP  ParCh     Fare Emb Deck
# 0           0      3    male  22.0      1      0   7.2500   S  NaN
# 4           0      3    male  35.0      0      0   8.0500   S  NaN
# 26          0      3    male   NaN      0      0   7.2250   C  NaN
# 28          1      3  female   NaN      0      0   7.8792   Q  NaN
# 29          0      3    male   NaN      0      0   7.8958   S  NaN
# ..        ...    ...     ...   ...    ...    ...      ...  ..  ...
# 776         0      3    male   NaN      0      0   7.7500   Q    F
# 784         0      3    male  25.0      0      0   7.0500   S  NaN
# 792         0      3  female   NaN      8      2  69.5500   S  NaN
# 795         0      2    male  39.0      0      0  13.0000   S  NaN
# 832         0      3    male   NaN      0      0   7.2292   C  NaN
#
# [123 rows x 9 columns]

# %%
titanic.duplicated(keep='last', subset=['Survived', 'Class']).sum()
# Out:
# 885

# %%
summer = pd.read_csv('summer.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.duplicated(keep='first').sum()
# Out:
# 2

# %%
summer.duplicated(keep=False).sum()
# Out:
# 4

# %%
summer.loc[summer.duplicated(keep=False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
summer.loc[~summer.duplicated(keep='first')].head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
basketball_2012 = summer.loc[(summer.Sport=='Basketball') & (summer.Year == 2012)]

# %%
basketball_2012.loc[basketball_2012.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete, Country, Gender, Event, Medal]
# Index: []

# %%
titanic.tail()
# Out:
#      Survived  Class  Gender   Age  SipSP  ParCh   Fare Emb Deck
# 886         0      2    male  27.0      0      0  13.00   S  NaN
# 887         1      1  female  19.0      0      0  30.00   S    B
# 888         0      3  female   NaN      1      2  23.45   S  NaN
# 889         1      1    male  26.0      0      0  30.00   C    C
# 890         0      3    male  32.0      0      0   7.75   Q  NaN

# %%
titanic.duplicated().sum()
# Out:
# 107

# %%
titanic[titanic.duplicated(keep='first')]
# Out:
#      Survived  Class  Gender   Age  SipSP  ParCh     Fare Emb Deck
# 47          1      3  female   NaN      0      0   7.7500   Q  NaN
# 76          0      3    male   NaN      0      0   7.8958   S  NaN
# 77          0      3    male   NaN      0      0   8.0500   S  NaN
# 87          0      3    male   NaN      0      0   8.0500   S  NaN
# 95          0      3    male   NaN      0      0   8.0500   S  NaN
# ..        ...    ...     ...   ...    ...    ...      ...  ..  ...
# 870         0      3    male  26.0      0      0   7.8958   S  NaN
# 877         0      3    male  19.0      0      0   7.8958   S  NaN
# 878         0      3    male   NaN      0      0   7.8958   S  NaN
# 884         0      3    male  25.0      0      0   7.0500   S  NaN
# 886         0      2    male  27.0      0      0  13.0000   S  NaN
#
# [107 rows x 9 columns]

# %%
titanic.tail()
# Out:
#      Survived  Class  Gender   Age  SipSP  ParCh   Fare Emb Deck
# 886         0      2    male  27.0      0      0  13.00   S  NaN
# 887         1      1  female  19.0      0      0  30.00   S    B
# 888         0      3  female   NaN      1      2  23.45   S  NaN
# 889         1      1    male  26.0      0      0  30.00   C    C
# 890         0      3    male  32.0      0      0   7.75   Q  NaN

# %%
titanic = pd.read_csv('titanic.csv', \
                      names=['Survived','Class','Gender','Age',\
                             'SipSP', 'ParCh','Fare','Emb',\
                             'Deck'], skiprows=1)

# %%
titanic.drop(["Deck"], axis=1, inplace=True)

# %%
titanic.duplicated(keep='first').sum()
# Out:
# 111

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Class     891 non-null    int64
#  2   Gender    891 non-null    object
#  3   Age       714 non-null    float64
#  4   SipSP     891 non-null    int64
#  5   ParCh     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Emb       889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
titanic.loc[titanic.duplicated(keep='first')]
# Out:
#      Survived  Class  Gender   Age  SipSP  ParCh     Fare Emb
# 47          1      3  female   NaN      0      0   7.7500   Q
# 76          0      3    male   NaN      0      0   7.8958   S
# 77          0      3    male   NaN      0      0   8.0500   S
# 87          0      3    male   NaN      0      0   8.0500   S
# 95          0      3    male   NaN      0      0   8.0500   S
# ..        ...    ...     ...   ...    ...    ...      ...  ..
# 863         0      3  female   NaN      8      2  69.5500   S
# 870         0      3    male  26.0      0      0   7.8958   S
# 877         0      3    male  19.0      0      0   7.8958   S
# 878         0      3    male   NaN      0      0   7.8958   S
# 884         0      3    male  25.0      0      0   7.0500   S
#
# [110 rows x 8 columns]

# %%
titanic.drop(index=[886], inplace=True)

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer[summer.duplicated(keep=False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
summer[(summer.Country=='IND') & (summer.Year==1980)]
# Out:
#        Year    City   Sport Discipline                   Athlete Country  \
# 16087  1980  Moscow  Hockey     Hockey          ALLAN, Schofield     IND
# 16088  1980  Moscow  Hockey     Hockey       AMARJIT RANA, Singh     IND
# 16089  1980  Moscow  Hockey     Hockey        BASKARAN, Baskaran     IND
# 16090  1980  Moscow  Hockey     Hockey          CHETTRI, Chettri     IND
# 16091  1980  Moscow  Hockey     Hockey          DEAVINDER, Singh     IND
# 16092  1980  Moscow  Hockey     Hockey         FERNANDES, Mervyn     IND
# 16093  1980  Moscow  Hockey     Hockey            GURMAIL, Singh     IND
# 16094  1980  Moscow  Hockey     Hockey  KAUSHIK, Maharaj Krishon     IND
# 16095  1980  Moscow  Hockey     Hockey          KUMAR, Charanjit     IND
# 16096  1980  Moscow  Hockey     Hockey        MANEYPANDA, Somaya     IND
# 16097  1980  Moscow  Hockey     Hockey          MOHAMMAD, Shahid     IND
# 16098  1980  Moscow  Hockey     Hockey              SINGH, Singh     IND
# ...

# %%
summer[(summer.Country=='CHN') & (summer.Year==2012)\
      & (summer.Athlete=='ZHAO, Yunlei')]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
import pandas as pd
alphabet = pd.DataFrame(['a','b','c','c','d','e','f','g','g','g'], columns=['alphabet'])

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
#   alphabet
# 2        c
# 3        c
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates(keep='first')
# Out:
#   alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 5        e
# 6        f
# 7        g

# %%
# alphabet.drop_duplicates(keep=False, inplace=True)

# %%
import pandas as pd

# %%
import pandas as pd
alphabet = pd.DataFrame(['a','b','c','c','d','e','f','g','g','g'], \
                        columns=['alphabet'])

# %%
alphabet
# Out:
#   alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        e
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   alphabet  7 non-null      object
# dtypes: object(1)
# memory usage: 112.0+ bytes

# %%
alphabet.drop_duplicates(ignore_index=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   alphabet  7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes

# %% [markdown]
# Detection of Outlier

# %%
titanic.head()
# Out:
#    Survived  Class  Gender   Age  SipSP  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C
# 2         1      3  female  26.0      0      0   7.9250   S
# 3         1      1  female  35.0      1      0  53.1000   S
# 4         0      3    male  35.0      0      0   8.0500   S

# %%
titanic.describe()
# Out:
#          Survived       Class         Age       SipSP       ParCh        Fare
# count  890.000000  890.000000  713.000000  890.000000  890.000000  890.000000
# mean     0.384270    2.308989   29.702903    0.523596    0.382022   32.225786
# std      0.486696    0.836477   14.536343    1.103224    0.806409   49.717193
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.903100
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.Fare.sort_values(ascending=False)
# Out:
# 737    512.3292
# 258    512.3292
# 679    512.3292
# 88     263.0000
# 438    263.0000
#          ...
# 815      0.0000
# 466      0.0000
# 806      0.0000
# 481      0.0000
# 597      0.0000
# Name: Fare, Length: 890, dtype: float64

# %%
titanic = pd.read_csv('titanic.csv', \
                      names=['Survived','Class','Gender','Age',\
                             'SipSP', 'ParCh','Fare','Emb',\
                             'Deck'], skiprows=1)

# %%
index = titanic.loc[titanic.Age > 70].index

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Class     891 non-null    int64
#  2   Gender    891 non-null    object
#  3   Age       714 non-null    float64
#  4   SipSP     891 non-null    int64
#  5   ParCh     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Emb       889 non-null    object
#  8   Deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.loc[titanic.Age > 70]
# Out:
#      Survived  Class Gender   Age  SipSP  ParCh     Fare Emb Deck
# 96          0      1   male  71.0      0      0  34.6542   C    A
# 116         0      3   male  70.5      0      0   7.7500   Q  NaN
# 493         0      1   male  71.0      0      0  49.5042   C  NaN
# 630         1      1   male  80.0      0      0  30.0000   S    A
# 851         0      3   male  74.0      0      0   7.7750   S  NaN

# %%
titanic.loc[titanic.Age > 70, 'Age'] = \
titanic.loc[titanic.Age > 70, 'Age']/10

# %%
titanic.loc[index]
# Out:
#      Survived  Class Gender   Age  SipSP  ParCh     Fare Emb Deck
# 96          0      1   male  7.10      0      0  34.6542   C    A
# 116         0      3   male  7.05      0      0   7.7500   Q  NaN
# 493         0      1   male  7.10      0      0  49.5042   C  NaN
# 630         1      1   male  8.00      0      0  30.0000   S    A
# 851         0      3   male  7.40      0      0   7.7750   S  NaN

# %%
titanic.nunique()
# Out:
# Survived      2
# Class         3
# Gender        2
# Age          87
# SipSP         7
# ParCh         7
# Fare        248
# Emb           3
# Deck          7
# dtype: int64

# %%
titanic.Emb = titanic.Emb.astype('category')
titanic.Gender = titanic.Gender.astype('category')

# %%
titanic.dtypes
# Out:
# Survived       int64
# Class          int64
# Gender      category
# Age          float64
# SipSP          int64
# ParCh          int64
# Fare         float64
# Emb         category
# Deck          object
# dtype: object

# %%
titanic.loc[:, ['Gender','Emb']].describe()
# Out:
#        Gender  Emb
# count     891  889
# unique      2    3
# top      male    S
# freq      577  644

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Class     891 non-null    int64
#  2   Gender    891 non-null    category
#  3   Age       714 non-null    float64
#  4   SipSP     891 non-null    int64
#  5   ParCh     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Emb       889 non-null    category
#  8   Deck      203 non-null    object
# dtypes: category(2), float64(2), int64(4), object(1)
# memory usage: 50.8+ KB

# %%
titanic.describe(include=['O'])
# Out:
#        Deck
# count   203
# unique    7
# top       C
# freq     59

# %%
titanic.describe(include=['category'])
# Out:
#        Gender  Emb
# count     891  889
# unique      2    3
# top      male    S
# freq      577  644

# %%
titanic.describe(include=['int'])
# Out:
#          Survived       Class       SipSP       ParCh
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.523008    0.381594
# std      0.486592    0.836071    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000    0.000000
# max      1.000000    3.000000    8.000000    6.000000

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    Int64
#  1   pclass    891 non-null    Int64
#  2   sex       891 non-null    string
#  3   age       714 non-null    Float64
#  4   sibsp     891 non-null    Int64
#  5   parch     891 non-null    Int64
#  6   fare      891 non-null    Float64
#  7   embarked  889 non-null    string
#  8   deck      203 non-null    string
# dtypes: Float64(2), Int64(4), string(3)
# memory usage: 68.0 KB

# %%
titanic_new_pd = titanic.convert_dtypes()

# %%
titanic_new_pd.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  deck
# 0         0       3    male  22.0      1      0     7.25        S  <NA>
# 1         1       1  female  38.0      1      0  71.2833        C     C
# 2         1       3  female  26.0      0      0    7.925        S  <NA>
# 3         1       1  female  35.0      1      0     53.1        S     C
# 4         0       3    male  35.0      0      0     8.05        S  <NA>

# %%
titanic_new_pd.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  deck
# 886         0       2    male  27.0      0      0   13.0        S  <NA>
# 887         1       1  female  19.0      0      0   30.0        S     B
# 888         0       3  female  <NA>      1      2  23.45        S  <NA>
# 889         1       1    male  26.0      0      0   30.0        C     C
# 890         0       3    male  32.0      0      0   7.75        Q  <NA>

# %%
titanic_new_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    Int64
#  1   pclass    891 non-null    Int64
#  2   sex       891 non-null    string
#  3   age       714 non-null    Float64
#  4   sibsp     891 non-null    Int64
#  5   parch     891 non-null    Int64
#  6   fare      891 non-null    Float64
#  7   embarked  889 non-null    string
#  8   deck      203 non-null    string
# dtypes: Float64(2), Int64(4), string(3)
# memory usage: 68.0 KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv("cars_unclean.csv")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
# 2  18.0          8         318.0   150.0 hp    3436          11.0          70
# 3  16.0          8         304.0   150.0 hp    3433          12.0          70
# 4  17.0          8         302.0   140.0 hp    3449          10.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320
# 2  United States           plymouth satellite
# 3            usa                amc rebel sst
# 4            usa                  FORD TORINO

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year  origin                          name
# 324          73     usa     mercury marquis brougham
# 325          76  europe                 renault 12tl
# 326          71     usa    chevrolet chevelle malibu
# 327          76     usa             ford gran torino
# 328          82     usa        buick century limited

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    329 non-null    object
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 23.3+ KB

# %%
cars.loc[cars.origin=='usa', 'origin'].head()
# Out:
# 3    usa
# 4    usa
# 5    usa
# 6    usa
# 7    usa
# Name: origin, dtype: object

# %%
cars.rename({'model year':'model_year'}, inplace=True)

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# name             object
# dtype: object

# %%
cars.origin.value_counts()
# Out:
# usa              254
# europe            72
# United States      3
# Name: origin, dtype: int64

# %%
cars.loc[cars.origin=='United States','origin'] = 'usa'

# %%
cars.origin.value_counts()
# Out:
# USA       257
# Europe     72
# Name: origin, dtype: int64

# %%
cars.origin.replace({"usa":"USA", "europe":"Europe"}, inplace=True)

# %%
cars.horsepower.head()
# Out:
# 0    130.0
# 1    165.0
# 2    150.0
# 3    150.0
# 4    140.0
# Name: horsepower, dtype: object

# %%
cars.horsepower = cars.horsepower.str.replace(" hp", "")

# %%
cars.horsepower.loc[cars.horsepower == 'Not available'].value_counts()
# Out:
# Not available    6
# Name: horsepower, dtype: int64

# %%
cars.horsepower.replace("Not available","", inplace=True)

# %%
cars.horsepower.replace("",np.nan, inplace=True)

# %%
cars.horsepower = cars.horsepower.astype('float')

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year origin                          name
# 0          70    usa    chevrolet chevelle malibu
# 1          70    usa            buick skylark 320
# 2          70    usa           plymouth satellite
# 3          70    usa                amc rebel sst
# 4          70    usa                  FORD TORINO

# %%
cars.horsepower.tail()
# Out:
# 324    198.0
# 325     83.0
# 326    100.0
# 327    152.0
# 328    110.0
# Name: horsepower, dtype: float64

# %%
cars.loc[4, 'name']
# Out:
# '  FORD TORINO '

# %%
cars.name = cars.name.str.lower().str.strip()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower        weight  \
# count  329.000000  329.000000    329.000000  323.000000    329.000000
# mean    21.655199    5.802432    217.004559  111.185759   3229.082067
# std      7.294651    1.719825    104.719009   39.846088   1376.306985
# min      0.060606    4.000000     68.000000   46.000000   1800.000000
# 25%     16.000000    4.000000    121.000000   83.500000   2464.000000
# 50%     20.200000    6.000000    200.000000  100.000000   3102.000000
# 75%     26.000000    8.000000    305.000000  141.000000   3821.000000
# max     44.300000    8.000000    455.000000  230.000000  23000.000000
#
#        acceleration   model year
# count    329.000000   329.000000
# mean      15.400000   104.495441
# std        2.922756   232.498690
# min        8.000000    70.000000
# 25%       13.500000    73.000000
# 50%       15.400000    76.000000
# 75%       17.000000    79.000000
# max       24.800000  1973.000000

# %%
cars.plot(subplots = True, figsize =(15, 12))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# name             object
# dtype: object

# %%
cars.rename(columns={'model year':'model_year'}, inplace=True)

# %%
cars.model_year.value_counts()
# Out:
# 73      33
# 76      32
# 70      29
# 78      28
# 79      27
# 75      26
# 71      25
# 72      23
# 82      23
# 74      22
# 77      22
# 80      17
# 81      17
# 1973     5
# Name: model_year, dtype: int64

# %%
cars.loc[cars.weight.idmax()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-247-d4ac2916b3af> in <module>
# ----> 1 cars.loc[cars.weight.idmax()]
#
# /trials/lab/python/anaconda3-4.10.1/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'idmax'

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
cars.loc[cars.weight.idxmax()]
# Out:
# mpg                   26.0
# cylinders                4
# displacement          97.0
# horsepower            78.0
# weight               23000
# acceleration          14.5
# model_year              74
# origin              europe
# name            opel manta
# Name: 126, dtype: object

# %%
cars.loc[cars.weight.idxmax(), 'weight'] = 2300

# %%
cars.loc[cars.weight.idxmin()]
# Out:
# mpg                    36.1
# cylinders                 4
# displacement           98.0
# horsepower             66.0
# weight                 1800
# acceleration           14.4
# model_year               78
# origin                  usa
# name            ford fiesta
# Name: 210, dtype: object

# %%
cars.loc[cars.mpg.idxmin(), 'mpg'] = 1/cars.loc[cars.mpg.idxmin(), 'mpg']

# %%
cars.loc[cars.isna().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28   25.0          4          98.0         NaN    2046          19.0
# 111  21.0          6         200.0         NaN    2875          17.0
# 276  40.9          4          85.0         NaN    1835          17.3
# 279  23.6          4         140.0         NaN    2905          14.3
# 290  34.5          4         100.0         NaN    2320          15.8
# 304  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 28           71     usa            ford pinto
# 111          74     usa         ford maverick
# 276          80  europe  renault lecar deluxe
# 279          80     usa    ford mustang cobra
# 290          81  europe           renault 18i
# 304          82     usa        amc concord dl

# %%
cars.duplicated(subset=['name'], keep=False).sum()
# Out:
# 137

# %%
cars.loc[cars.duplicated(subset=['name'], keep=False)].sort_values(by='name')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 323  24.3          4         151.0        90.0    3003          20.1
# 219  19.4          6         232.0        90.0    3210          17.2
# 268  24.3          4         151.0        90.0    3003          20.1
# 96   18.0          6         232.0       100.0    2789          15.0
# 29   19.0          6         232.0       100.0    2634          13.0
# ..    ...        ...           ...         ...     ...           ...
# 172  29.0          4          90.0        70.0    1937          14.2
# 177  29.5          4          97.0        71.0    1825          12.2
# 277  29.8          4          89.0        62.0    1845          15.3
# 250  31.9          4          89.0        71.0    1925          14.0
# 202  29.0          4          97.0        78.0    1940          14.5
#
#      model_year  origin              name
# 323          80     usa       amc concord
# 219          78     usa       amc concord
# ...

# %% [markdown]
# Into

# %% [markdown]
# Adding / Concatenating Rows

# %%
import pandas as pd

# %%
men2004 = pd.read_csv('men2004.csv')

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008 = pd.read_csv('men2008.csv')

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.append(men2008, ignore_index=False)
# Out:
#              Athlete  Medals
# 0    PHELPS, Michael       8
# 1        THORPE, Ian       4
# 2   SCHOEMAN, Roland       3
# 3     PEIRSOL, Aaron       3
# 4       CROCKER, Ian       3
# ..               ...     ...
# 57  LAGUNOV, Evgeniy       1
# 58     BERENS, Ricky       1
# 59      LURZ, Thomas       1
# 60   MALLET, Gregory       1
# 61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men2004.append(men2008, ignore_index=True)
# Out:
#               Athlete  Medals
# 0     PHELPS, Michael       8
# 1         THORPE, Ian       4
# 2    SCHOEMAN, Roland       3
# 3      PEIRSOL, Aaron       3
# 4        CROCKER, Ian       3
# ..                ...     ...
# 116  LAGUNOV, Evgeniy       1
# 117     BERENS, Ricky       1
# 118      LURZ, Thomas       1
# 119   MALLET, Gregory       1
# 120        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
pd.concat([men2004, men2008], ignore_index=False, keys=None)
# Out:
#              Athlete  Medals
# 0    PHELPS, Michael       8
# 1        THORPE, Ian       4
# 2   SCHOEMAN, Roland       3
# 3     PEIRSOL, Aaron       3
# 4       CROCKER, Ian       3
# ..               ...     ...
# 57  LAGUNOV, Evgeniy       1
# 58     BERENS, Ricky       1
# 59      LURZ, Thomas       1
# 60   MALLET, Gregory       1
# 61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
pd.concat([men2004, men2008], ignore_index=True, keys=None)
# Out:
#               Athlete  Medals
# 0     PHELPS, Michael       8
# 1         THORPE, Ian       4
# 2    SCHOEMAN, Roland       3
# 3      PEIRSOL, Aaron       3
# 4        CROCKER, Ian       3
# ..                ...     ...
# 116  LAGUNOV, Evgeniy       1
# 117     BERENS, Ricky       1
# 118      LURZ, Thomas       1
# 119   MALLET, Gregory       1
# 120        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
pd.concat([men2004, men2008], ignore_index=False, keys=[2004, 2008])
# Out:
#                   Athlete  Medals
# 2004 0    PHELPS, Michael       8
#      1        THORPE, Ian       4
#      2   SCHOEMAN, Roland       3
#      3     PEIRSOL, Aaron       3
#      4       CROCKER, Ian       3
# ...                   ...     ...
# 2008 57  LAGUNOV, Evgeniy       1
#      58     BERENS, Ricky       1
#      59      LURZ, Thomas       1
#      60   MALLET, Gregory       1
#      61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men_2004_2008= pd.concat([men2004, men2008], ignore_index=False, keys=[2004, 2008]\
         , names=["Year"])

# %%
men_2004_2008.reset_index().drop(columns="level_1")
# Out:
#      Year           Athlete  Medals
# 0    2004   PHELPS, Michael       8
# 1    2004       THORPE, Ian       4
# 2    2004  SCHOEMAN, Roland       3
# 3    2004    PEIRSOL, Aaron       3
# 4    2004      CROCKER, Ian       3
# ..    ...               ...     ...
# 116  2008  LAGUNOV, Evgeniy       1
# 117  2008     BERENS, Ricky       1
# 118  2008      LURZ, Thomas       1
# 119  2008   MALLET, Gregory       1
# 120  2008        ZHANG, Lin       1
#
# [121 rows x 3 columns]

# %%
men2004.columns = ["Name", "Medals"]

# %%
men2004["Success"] = "Yes"

# %%
men2004 = pd.read_csv('men2004.csv', index_col='Athlete')
men2008 = pd.read_csv('men2008.csv', index_col='Athlete')

# %%
pd.concat([men2004, men2008], ignore_index=False, keys = [2004, 2008])
# Out:
#                        Medals
#      Athlete
# 2004 PHELPS, Michael        8
#      THORPE, Ian            4
#      SCHOEMAN, Roland       3
#      PEIRSOL, Aaron         3
#      CROCKER, Ian           3
# ...                       ...
# 2008 LAGUNOV, Evgeniy       1
#      BERENS, Ricky          1
#      LURZ, Thomas           1
#      MALLET, Gregory        1
#      ZHANG, Lin             1
#
# [121 rows x 1 columns]

# %%
import pandas as pd

# %%
topfive_2004 = pd.read_csv("topfive_2004.csv", index_col='Athlete')
topfive_2008 = pd.read_csv("topfive_2008.csv", index_col='Athlete')

# %%
topfive_2004
# Out:
#                   Gold  Silver  Bronze
# Athlete
# PHELPS, Michael    6.0     0.0     2.0
# PEIRSOL, Aaron     3.0     0.0     0.0
# THORPE, Ian        2.0     1.0     1.0
# KITAJIMA, Kosuke   2.0     0.0     1.0
# HACKETT, Grant     1.0     2.0     0.0

# %%
topfive_2008
# Out:
#                   Gold  Silver  bronze
# Athlete
# PHELPS, Michael    8.0     0.0     0.0
# GREVERS, Matt      2.0     1.0     0.0
# PEIRSOL, Aaron     2.0     1.0     0.0
# LOCHTE, Ryan       2.0     0.0     2.0
# KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
topfive_2004 + topfive_2008
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   NaN     NaN     NaN
# HACKETT, Grant       NaN   NaN     NaN     NaN
# KITAJIMA, Kosuke     NaN   4.0     0.0     NaN
# LOCHTE, Ryan         NaN   NaN     NaN     NaN
# PEIRSOL, Aaron       NaN   5.0     1.0     NaN
# PHELPS, Michael      NaN  14.0     0.0     NaN
# THORPE, Ian          NaN   NaN     NaN     NaN

# %%
topfive_2004.add(topfive_2008, fill_value=0)
# Out:
#                   Bronze  Gold  Silver  bronze
# Athlete
# GREVERS, Matt        NaN   2.0     1.0     0.0
# HACKETT, Grant       0.0   1.0     2.0     NaN
# KITAJIMA, Kosuke     1.0   4.0     0.0     1.0
# LOCHTE, Ryan         NaN   2.0     0.0     2.0
# PEIRSOL, Aaron       0.0   5.0     1.0     0.0
# PHELPS, Michael      2.0  14.0     0.0     0.0
# THORPE, Ian          1.0   2.0     1.0     NaN

# %%
topfive_2008.rename(columns={"bronze":"Bronze"}, inplace=True)

# %%
topfive_2004.add(topfive_2008, fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt      2.0     1.0     0.0
# HACKETT, Grant     1.0     2.0     0.0
# KITAJIMA, Kosuke   4.0     0.0     2.0
# LOCHTE, Ryan       2.0     0.0     2.0
# PEIRSOL, Aaron     5.0     1.0     0.0
# PHELPS, Michael   14.0     0.0     2.0
# THORPE, Ian        2.0     1.0     1.0

# %%
topfive_2004.sub(topfive_2008, fill_value=0)
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt     -2.0    -1.0     0.0
# HACKETT, Grant     1.0     2.0     0.0
# KITAJIMA, Kosuke   0.0     0.0     0.0
# LOCHTE, Ryan      -2.0     0.0    -2.0
# PEIRSOL, Aaron     1.0    -1.0     0.0
# PHELPS, Michael   -2.0     0.0     2.0
# THORPE, Ian        2.0     1.0     1.0

# %% [markdown]
# Outer Join

# %%
import pandas as pd

# %%
men2004 = pd.read_csv("men2004.csv")

# %%
men2008 = pd.read_csv("men2008.csv")

# %%
men2004.shape
# Out:
# (59, 2)

# %%
men2008.shape
# Out:
# (62, 2)

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
len(men2008) + len(men2004)
# Out:
# 121

# %%
men2004.merge(men2008, how='outer', on='Athlete', suffixes=('_2004','_2008')\
             ,indicator=True)
# Out:
#               Athlete  Medals_2004  Medals_2008      _merge
# 0     PHELPS, Michael          8.0          8.0        both
# 1         THORPE, Ian          4.0          NaN   left_only
# 2    SCHOEMAN, Roland          3.0          NaN   left_only
# 3      PEIRSOL, Aaron          3.0          3.0        both
# 4        CROCKER, Ian          3.0          1.0        both
# ..                ...          ...          ...         ...
# 100  LAGUNOV, Evgeniy          NaN          1.0  right_only
# 101     BERENS, Ricky          NaN          1.0  right_only
# 102      LURZ, Thomas          NaN          1.0  right_only
# 103   MALLET, Gregory          NaN          1.0  right_only
# 104        ZHANG, Lin          NaN          1.0  right_only
#
# [105 rows x 4 columns]

# %%
men_2004_2008 = men2004.merge(men2008, how='outer', on='Athlete', suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men_2004_2008.loc[men_2004_2008._merge=='right_only']
# Out:
#                       Athlete  Medals_2004  Medals_2008      _merge
# 59             BERNARD, Alain          NaN          3.0  right_only
# 60            SULLIVAN, Eamon          NaN          3.0  right_only
# 61        LAUTERSTEIN, Andrew          NaN          3.0  right_only
# 62              GREVERS, Matt          NaN          3.0  right_only
# 63           RICKARD, Brenton          NaN          2.0  right_only
# 64            LEVEAUX, Amaury          NaN          2.0  right_only
# 65           STOECKEL, Hayden          NaN          2.0  right_only
# 66              TARGETT, Matt          NaN          2.0  right_only
# 67              PARK, Taehwan          NaN          2.0  right_only
# 68         CIELO FILHO, Cesar          NaN          2.0  right_only
# 69         VYATCHANIN, Arkady          NaN          2.0  right_only
# 70              BRODIE, Leith          NaN          2.0  right_only
# 71        WEBER-GALE, Garrett          NaN          2.0  right_only
# ...

# %%
men_2004_2008._merge.value_counts()
# Out:
# right_only    46
# left_only     43
# both          16
# Name: _merge, dtype: int64

# %% [markdown]
# Inner Join

# %%
men2004.merge(men2008, how='inner', on='Athlete', suffixes=('_2004','_2008')\
             , indicator=True)
# Out:
#               Athlete  Medals_2004  Medals_2008 _merge
# 0     PHELPS, Michael            8            8   both
# 1      PEIRSOL, Aaron            3            3   both
# 2        CROCKER, Ian            3            1   both
# 3    KITAJIMA, Kosuke            3            3   both
# 4     HANSEN, Brendan            3            1   both
# 5      HACKETT, Grant            3            2   both
# 6        LEZAK, Jason            2            3   both
# 7       KELLER, Klete            2            1   both
# 8        LOCHTE, Ryan            2            4   both
# 9         VENDT, Erik            1            1   both
# 10  VANDERKAAY, Peter            1            2   both
# 11       CSEH, Laszlo            1            3   both
# 12      DAVIES, David            1            1   both
# 13    DUBOSCQ, Hugues            1            2   both
# 14     GANGLOFF, Mark            1            1   both
# 15     JENSEN, Larsen            1            1   both

# %%
# Out:
#              Athlete_2004  Medals_2004      Athlete_2008  Medals_2008 _merge
# 3653  ZWERING, Klaas-Erik            1  LAGUNOV, Evgeniy            1   both
# 3654  ZWERING, Klaas-Erik            1     BERENS, Ricky            1   both
# 3655  ZWERING, Klaas-Erik            1      LURZ, Thomas            1   both
# 3656  ZWERING, Klaas-Erik            1   MALLET, Gregory            1   both
# 3657  ZWERING, Klaas-Erik            1        ZHANG, Lin            1   both

# %%
men_2004_2008 = men2004.merge(men2008, how='outer', on='Athlete', suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men_2004_2008.loc[men_2004_2008._merge != 'both']
# Out:
#                         Athlete  Medals_2004  Medals_2008      _merge
# 1                   THORPE, Ian          4.0          NaN   left_only
# 2              SCHOEMAN, Roland          3.0          NaN   left_only
# 7    VAN DEN HOOGENBAND, Pieter          3.0          NaN   left_only
# 9                MORITA, Tomomi          2.0          NaN   left_only
# 11                ROGAN, Markus          2.0          NaN   left_only
# ..                          ...          ...          ...         ...
# 100            LAGUNOV, Evgeniy          NaN          1.0  right_only
# 101               BERENS, Ricky          NaN          1.0  right_only
# 102                LURZ, Thomas          NaN          1.0  right_only
# 103             MALLET, Gregory          NaN          1.0  right_only
# 104                  ZHANG, Lin          NaN          1.0  right_only
#
# [89 rows x 4 columns]

# %% [markdown]
# Left join (without intersection)

# %%
men2004.head(2)
# Out:
#            Athlete  Medals
# 0  PHELPS, Michael       8
# 1      THORPE, Ian       4

# %%
men2008.head(2)
# Out:
#            Athlete  Medals
# 0  PHELPS, Michael       8
# 1     LOCHTE, Ryan       4

# %%
men2004_2008 = men2004.merge(men2008, how='outer', on='Athlete',\
                             suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men2004_2008.head()
# Out:
#             Athlete  Medals_2004  Medals_2008     _merge
# 0   PHELPS, Michael          8.0          8.0       both
# 1       THORPE, Ian          4.0          NaN  left_only
# 2  SCHOEMAN, Roland          3.0          NaN  left_only
# 3    PEIRSOL, Aaron          3.0          3.0       both
# 4      CROCKER, Ian          3.0          1.0       both

# %%
men2004_2008.loc[men2004_2008._merge=='left_only']
# Out:
#                        Athlete  Medals_2004  Medals_2008     _merge
# 1                  THORPE, Ian          4.0          NaN  left_only
# 2             SCHOEMAN, Roland          3.0          NaN  left_only
# 7   VAN DEN HOOGENBAND, Pieter          3.0          NaN  left_only
# 9               MORITA, Tomomi          2.0          NaN  left_only
# 11               ROGAN, Markus          2.0          NaN  left_only
# 13              HALL, Gary Jr.          2.0          NaN  left_only
# 15                WALKER, Neil          2.0          NaN  left_only
# 16           YAMAMOTO, Takashi          2.0          NaN  left_only
# 17          SPRENGER, Nicholas          1.0          NaN  left_only
# 18          OKUMURA, Yoshihiro          1.0          NaN  left_only
# 19              PARRY, Stephen          1.0          NaN  left_only
# 20               PEARSON, Todd          1.0          NaN  left_only
# 21              ZASTROW, Mitja          1.0          NaN  left_only
# ...

# %%
men2004_2008.loc[men2004_2008._merge=='left_only'].shape
# Out:
# (43, 4)

# %%
men2004_2008.loc[men2004_2008._merge=='right_only'].shape
# Out:
# (46, 4)

# %%
men2004_2008.loc[men2004_2008._merge=='both'].shape
# Out:
# (16, 4)

# %%
men2004_2008_left = men2004.merge(men2008, how='left', on='Athlete',\
                             suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men2004_2008_left.shape
# Out:
# (59, 4)

# %%
men2004_2008_right = men2004.merge(men2008, how='right', on='Athlete',\
                             suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men2004_2008_right.shape
# Out:
# (62, 4)

# %% [markdown]
# Joining on different Column labels and indexes

# %%
import pandas as pd

# %%
men2004 = pd.read_csv('men2004.csv')
men2008 = pd.read_csv('men2008.csv')

# %%
men2004.rename(columns={"Athlete":"Name"}, inplace=True)
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men0408 = men2004.merge(men2008, how='outer', left_on='Name', right_on='Athlete', \
             suffixes=('_2004','_2008'),indicator=True)

# %%
men0408.head()
# Out:
#                Name  Medals_2004          Athlete  Medals_2008     _merge
# 0   PHELPS, Michael          8.0  PHELPS, Michael          8.0       both
# 1       THORPE, Ian          4.0              NaN          NaN  left_only
# 2  SCHOEMAN, Roland          3.0              NaN          NaN  left_only
# 3    PEIRSOL, Aaron          3.0   PEIRSOL, Aaron          3.0       both
# 4      CROCKER, Ian          3.0     CROCKER, Ian          1.0       both

# %%
men0408.Name.fillna(men0408.Athlete, inplace=True)

# %%
men0408.drop(['Athlete','_merge'], axis=1, inplace=True)

# %%
men0408.head()
# Out:
#                Name  Medals_2004  Medals_2008
# 0   PHELPS, Michael          8.0          8.0
# 1       THORPE, Ian          4.0          NaN
# 2  SCHOEMAN, Roland          3.0          NaN
# 3    PEIRSOL, Aaron          3.0          3.0
# 4      CROCKER, Ian          3.0          1.0

# %%
men2004.head()
# Out:
#                Name  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2008.set_index('Athlete', inplace=True)

# %%
men2004.merge(men2008, how='outer', left_on='Name',\
                             right_index=True,suffixes=('_2004','_2008')\
             ,indicator=True)
# Out:
#                  Name  Medals_2004  Medals_2008      _merge
# 0.0   PHELPS, Michael          8.0          8.0        both
# 1.0       THORPE, Ian          4.0          NaN   left_only
# 2.0  SCHOEMAN, Roland          3.0          NaN   left_only
# 3.0    PEIRSOL, Aaron          3.0          3.0        both
# 4.0      CROCKER, Ian          3.0          1.0        both
# ..                ...          ...          ...         ...
# NaN  LAGUNOV, Evgeniy          NaN          1.0  right_only
# NaN     BERENS, Ricky          NaN          1.0  right_only
# NaN      LURZ, Thomas          NaN          1.0  right_only
# NaN   MALLET, Gregory          NaN          1.0  right_only
# NaN        ZHANG, Lin          NaN          1.0  right_only
#
# [105 rows x 4 columns]

# %%
men2008.merge(men2004, how='outer', left_index=True,\
                             right_on='Name',suffixes=('_2004','_2008')\
             ,indicator=True)
# Out:
#       Medals_2004                 Name  Medals_2008      _merge
# 0.0           8.0      PHELPS, Michael          8.0        both
# 14.0          4.0         LOCHTE, Ryan          2.0        both
# NaN           3.0       BERNARD, Alain          NaN   left_only
# NaN           3.0      SULLIVAN, Eamon          NaN   left_only
# NaN           3.0  LAUTERSTEIN, Andrew          NaN   left_only
# ...           ...                  ...          ...         ...
# 54.0          NaN   KRAYZELBURG, Lenny          1.0  right_only
# 55.0          NaN         KRUPPA, Jens          1.0  right_only
# 56.0          NaN  BREMBILLA, Emiliano          1.0  right_only
# 57.0          NaN     MAGNINI, Filippo          1.0  right_only
# 58.0          NaN  ZWERING, Klaas-Erik          1.0  right_only
#
# [105 rows x 4 columns]

# %% [markdown]
# Joining on mant columns

# %%
import pandas as pd

# %%
men2004_det = pd.read_csv('men2004_det.csv')
men2008_det = pd.read_csv('men2008_det.csv')

# %%
men2004_det.loc[men2004_det.Athlete=='PHELPS, Michael']
# Out:
#             Athlete   Medal  Count
# 50  PHELPS, Michael  Bronze      2
# 51  PHELPS, Michael    Gold      6

# %%
men2008_det.loc[men2008_det.Athlete=='PHELPS, Michael']
# Out:
#             Athlete Medal  Count
# 54  PHELPS, Michael  Gold      8

# %%
men0408_det = men2004_det.merge(men2008_det, how='outer'\
                               ,on='Athlete', suffixes=('_2004','_2008'))

# %%
men0408_det.loc[men0408_det.Athlete=='PHELPS, Michael']
# Out:
#             Athlete Medal_2004  Count_2004 Medal_2008  Count_2008
# 59  PHELPS, Michael     Bronze         2.0       Gold         8.0
# 60  PHELPS, Michael       Gold         6.0       Gold         8.0

# %%
men0408_det_new = men2004_det.merge(men2008_det, how='outer'\
                               ,on=['Athlete', 'Medal'], suffixes=('_2004','_2008'))

# %%
men0408_det_new.loc[men0408_det_new.Athlete=='PHELPS, Michael']
# Out:
#             Athlete   Medal  Count_2004  Count_2008
# 50  PHELPS, Michael  Bronze         2.0         NaN
# 51  PHELPS, Michael    Gold         6.0         8.0

# %% [markdown]
# pd.merge and join()

# %%
men2004 = pd.read_csv('men2004.csv', index_col='Athlete')
men2008 = pd.read_csv('men2008.csv', index_col='Athlete')

# %%
men2004.head()
# Out:
#                   Medals
# Athlete
# PHELPS, Michael        8
# THORPE, Ian            4
# SCHOEMAN, Roland       3
# PEIRSOL, Aaron         3
# CROCKER, Ian           3

# %%
men2008.head()
# Out:
#                      Medals
# Athlete
# PHELPS, Michael           8
# LOCHTE, Ryan              4
# BERNARD, Alain            3
# SULLIVAN, Eamon           3
# LAUTERSTEIN, Andrew       3

# %%
men0408 = men2004.merge(men2008, how='outer', on='Athlete',\
                             suffixes=('_2004','_2008')\
             ,indicator=True)

# %%
men0408.head()
# Out:
#                   Medals_2004  Medals_2008     _merge
# Athlete
# PHELPS, Michael           8.0          8.0       both
# THORPE, Ian               4.0          NaN  left_only
# SCHOEMAN, Roland          3.0          NaN  left_only
# PEIRSOL, Aaron            3.0          3.0       both
# CROCKER, Ian              3.0          1.0       both

# %%
pd.merge(men2004, men2008, how='outer', on='Athlete',\
                             suffixes=('_2004','_2008')\
             ,indicator=True)
# Out:
#                   Medals_2004  Medals_2008      _merge
# Athlete
# PHELPS, Michael           8.0          8.0        both
# THORPE, Ian               4.0          NaN   left_only
# SCHOEMAN, Roland          3.0          NaN   left_only
# PEIRSOL, Aaron            3.0          3.0        both
# CROCKER, Ian              3.0          1.0        both
# ...                       ...          ...         ...
# LAGUNOV, Evgeniy          NaN          1.0  right_only
# BERENS, Ricky             NaN          1.0  right_only
# LURZ, Thomas              NaN          1.0  right_only
# MALLET, Gregory           NaN          1.0  right_only
# ZHANG, Lin                NaN          1.0  right_only
#
# [105 rows x 3 columns]

# %%
men2004.join(men2008, how='outer', \
                             lsuffix='_2004', rsuffix='_2008')
# Out:
#                      Medals_2004  Medals_2008
# Athlete
# ADRIAN, Nathan               NaN          1.0
# BERENS, Ricky                NaN          1.0
# BERNARD, Alain               NaN          3.0
# BOUSQUET, Frederick          NaN          1.0
# BOVELL, George               1.0          NaN
# ...                          ...          ...
# WOODWARD, Gabe               1.0          NaN
# YAMAMOTO, Takashi            2.0          NaN
# ZASTROW, Mitja               1.0          NaN
# ZHANG, Lin                   NaN          1.0
# ZWERING, Klaas-Erik          1.0          NaN
#
# [105 rows x 2 columns]

# %% [markdown]
# Pandas GroupBy Operation

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic_slice = titanic.iloc[:10, [2,3]]

# %%
titanic_slice.tail()
# Out:
#       sex   age
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# 8  female  27.0
# 9  female  14.0

# %%
gbo = titanic_slice.groupby('sex')

# %%
type(gbo)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
gbo.groups
# Out:
# {'female': [1, 2, 3, 8, 9], 'male': [0, 4, 5, 6, 7]}

# %%
l = list(gbo)

# %%
l
# Out:
# [('female',
#         sex   age
#   1  female  38.0
#   2  female  26.0
#   3  female  35.0
#   8  female  27.0
#   9  female  14.0),
#  ('male',
#       sex   age
#   0  male  22.0
#   4  male  35.0
#   5  male   NaN
#   6  male  54.0
#   7  male   2.0)]

# %%
len(l)
# Out:
# 2

# %%
l[0][1]
# Out:
#       sex   age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 8  female  27.0
# 9  female  14.0

# %%
l[1]
# Out:
# ('male',
#      sex   age
#  0  male  22.0
#  4  male  35.0
#  5  male   NaN
#  6  male  54.0
#  7  male   2.0)

# %%
type(l[0])
# Out:
# tuple

# %%
type(l[1])
# Out:
# tuple

# %%
type(l[0][1])
# Out:
# pandas.core.frame.DataFrame

# %%
type(l[1][1])
# Out:
# pandas.core.frame.DataFrame

# %%
type(l[1][0])
# Out:
# str

# %%
titanic_slice_f = titanic_slice.loc[titanic_slice.sex == "female"]

# %%
titanic_slice_m = titanic_slice.loc[titanic_slice.sex == "male"]

# %%
titanic_slice_f.equals(l[0][1])
# Out:
# True

# %%
titanic_slice_m.equals(l[1][1])
# Out:
# True

# %%
for element in gbo:
    print(element[1])
# Out:
#       sex   age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 8  female  27.0
# 9  female  14.0
#     sex   age
# 0  male  22.0
# 4  male  35.0
# 5  male   NaN
# 6  male  54.0
# 7  male   2.0

# %% [markdown]
# Splitting with many Keys

# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.Country.nunique()
# Out:
# 147

# %%
split1 = summer.groupby('Country')

# %%
l = list(split1)

# %%
l
# Out:
# [('AFG',
#          Year     City      Sport Discipline           Athlete Country Gender  \
#   28965  2008  Beijing  Taekwondo  Taekwondo  NIKPAI, Rohullah     AFG    Men
#   30929  2012   London  Taekwondo  Taekwondo  NIKPAI, Rohullah     AFG    Men
#
#               Event   Medal
#   28965     - 58 KG  Bronze
#   30929  58 - 68 KG  Bronze  ),
#  ('AHO',
#          Year   City    Sport Discipline          Athlete Country Gender  \
#   19323  1988  Seoul  Sailing    Sailing  BOERSMA, Jan D.     AHO    Men
#
#                        Event   Medal
#   19323  Board (Division Ii)  Silver  ),
#  ('ALG',
#          Year         City      Sport Discipline               Athlete Country  \
#   17060  1984  Los Angeles     Boxing     Boxing        ZAOUI, Mohamed     ALG
#   17064  1984  Los Angeles     Boxing     Boxing      MOUSSA, Mustapha     ALG
#   19874  1992    Barcelona  Athletics  Athletics    BOULMERKA, Hassiba     ALG
# ...

# %%
len(l)
# Out:
# 147

# %%
l[100][0]
# Out:
# 'PHI'

# %%
l[100][1]
# Out:
#        Year         City      Sport Discipline                 Athlete  \
# 5031   1928    Amsterdam   Aquatics   Swimming      YLDEFONSO, Teofilo
# 5741   1932  Los Angeles   Aquatics   Swimming      YLDEFONSO, Teofilo
# 5889   1932  Los Angeles  Athletics  Athletics  TORIBIO, Simeon Galvez
# 5922   1932  Los Angeles     Boxing     Boxing        VILLANUEVA, Jose
# 6447   1936       Berlin  Athletics  Athletics        WHITE, Miguel S.
# 11005  1964        Tokyo     Boxing     Boxing  VILLANUEVA, Anthony N.
# 18513  1988        Seoul     Boxing     Boxing      SERANTES, Leopoldo
# 20184  1992    Barcelona     Boxing     Boxing           VELASCO, Roel
# 21927  1996      Atlanta     Boxing     Boxing       VELASCO, Mansueto
#
#       Country Gender                       Event   Medal
# 5031      PHI    Men           200M Breaststroke  Bronze
# 5741      PHI    Men           200M Breaststroke  Bronze
# 5889      PHI    Men                   High Jump  Bronze
# ...

# %%
split2 = summer.groupby(by=['Country','Gender'])

# %%
l2 = list(split2)

# %%
l2
# Out:
# [(('AFG', 'Men'),
#          Year     City      Sport Discipline           Athlete Country Gender  \
#   28965  2008  Beijing  Taekwondo  Taekwondo  NIKPAI, Rohullah     AFG    Men
#   30929  2012   London  Taekwondo  Taekwondo  NIKPAI, Rohullah     AFG    Men
#
#               Event   Medal
#   28965     - 58 KG  Bronze
#   30929  58 - 68 KG  Bronze  ),
#  (('AHO', 'Men'),
#          Year   City    Sport Discipline          Athlete Country Gender  \
#   19323  1988  Seoul  Sailing    Sailing  BOERSMA, Jan D.     AHO    Men
#
#                        Event   Medal
#   19323  Board (Division Ii)  Silver  ),
#  (('ALG', 'Men'),
#          Year         City      Sport Discipline               Athlete Country  \
#   17060  1984  Los Angeles     Boxing     Boxing        ZAOUI, Mohamed     ALG
#   17064  1984  Los Angeles     Boxing     Boxing      MOUSSA, Mustapha     ALG
#   20200  1992    Barcelona     Boxing     Boxing       SOLTANI, Hocine     ALG
# ...

# %%
len(l2)
# Out:
# 236

# %%
l2[104][0]
# Out:
# ('IRL', 'Women')

# %%
l2[104][1]
# Out:
#        Year     City      Sport Discipline                Athlete Country  \
# 21356  1996  Atlanta   Aquatics   Swimming  SMITH, Michelle Marie     IRL
# 21369  1996  Atlanta   Aquatics   Swimming  SMITH, Michelle Marie     IRL
# 21375  1996  Atlanta   Aquatics   Swimming  SMITH, Michelle Marie     IRL
# 21381  1996  Atlanta   Aquatics   Swimming  SMITH, Michelle Marie     IRL
# 23627  2000   Sydney  Athletics  Athletics      O'SULLIVAN, Sonia     IRL
# 29896  2012   London     Boxing     Boxing          TAYLOR, Katie     IRL
#
#       Gender                   Event   Medal
# 21356  Women          200M Butterfly  Bronze
# 21369  Women  200M Individual Medley    Gold
# 21375  Women          400M Freestyle    Gold
# 21381  Women  400M Individual Medley    Gold
# 23627  Women                   5000M  Silver
# 29896  Women                   60 KG    Gold

# %% [markdown]
# split-apply-combine explained

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic_slice = titanic.iloc[:10, [2,3]]

# %%
titanic_slice
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# 8  female  27.0
# 9  female  14.0

# %%
list(titanic_slice.groupby('sex'))[0][1]
# Out:
#       sex   age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 8  female  27.0
# 9  female  14.0

# %%
list(titanic_slice.groupby('sex'))[1][1]
# Out:
#     sex   age
# 0  male  22.0
# 4  male  35.0
# 5  male   NaN
# 6  male  54.0
# 7  male   2.0

# %%
titanic_slice.groupby('sex').mean()
# Out:
#           age
# sex
# female  28.00
# male    28.25

# %%
list(titanic_slice.groupby('sex'))[1][1].mean()
# Out:
# age    28.25
# dtype: float64

# %%
list(titanic_slice.groupby('sex'))[0][1].mean()
# Out:
# age    28.0
# dtype: float64

# %%
titanic.groupby('sex')

# %%
list(titanic.groupby('sex'))[0][1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [314 rows x 9 columns]

# %%
titanic.groupby('sex').mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893

# %%
list(titanic.groupby('sex'))[0][1].mean()
# Out:
# survived     0.742038
# pclass       2.159236
# age         27.915709
# sibsp        0.694268
# parch        0.649682
# fare        44.479818
# dtype: float64

# %%
titanic.groupby('sex').sum()
# Out:
#         survived  pclass       age  sibsp  parch        fare
# sex
# female       233     678   7286.00    218    204  13966.6628
# male         109    1379  13919.17    248    136  14727.2865

# %%
titanic.groupby('sex').survived.sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
titanic.groupby('sex')['fare','age'].sum()
# Out:
# <ipython-input-81-ae535bce3d53>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   titanic.groupby('sex')['fare','age'].sum()
#               fare       age
# sex
# female  13966.6628   7286.00
# male    14727.2865  13919.17

# %%
titanic.groupby('sex')[['fare','age']].sum()
# Out:
#               fare       age
# sex
# female  13966.6628   7286.00
# male    14727.2865  13919.17

# %%
new_df = titanic.groupby('sex').mean()

# %%
new_df
# Out:
#         survived    pclass        age     sibsp     parch       fare
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
new_df.plot(kind='bar', subplots = True, figsize = (8, 15), fontsize = 13)
# Out:
# array([<AxesSubplot:title={'center':'survived'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'pclass'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'age'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'sibsp'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'parch'}, xlabel='sex'>,
#        <AxesSubplot:title={'center':'fare'}, xlabel='sex'>], dtype=object)

# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
medals_per_country = summer.groupby('Country')[['Medal']].count()

# %%
medals_per_country.head()
# Out:
#          Medal
# Country
# AFG          2
# AHO          1
# ALG         15
# ANZ         29
# ARG        259

# %%
medals_per_country['Medal'].nlargest(n=10)
# Out:
# Country
# USA    4585
# URS    2049
# GBR    1720
# FRA    1396
# GER    1305
# ITA    1296
# AUS    1189
# HUN    1079
# SWE    1044
# NED     851
# Name: Medal, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
medals_per_country.iloc[:20].plot(kind = 'bar', figsize = (14, 8), \
                                  fontsize = 14)
plt.xlabel("Country", fontsize = 13)
plt.ylabel("No. of Medals", fontsize = 13)
plt.title("Summer Olympic Games (Total Medals per Country)", fontsize = 16)
plt.show()

# %%
import pandas as pd
titanic = pd.read_csv('titanic.csv')

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.fare.mean()
# Out:
# 32.2042079685746

# %%
titanic.groupby("pclass").fare.mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
titanic.survived.mean()
# Out:
# 0.3838383838383838

# %%
titanic.groupby("sex").survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby("pclass").survived.mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
titanic['adult_child'] = 'adult'

# %%
titanic.loc[titanic.age < 18, 'adult_child'] = 'child'

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#   adult_child
# 0       adult
# 1       adult
# 2       adult
# 3       adult
# 4       adult

# %%
titanic.groupby('adult_child').mean()
# Out:
#              survived    pclass        age     sibsp     parch       fare
# adult_child
# adult        0.361183  2.268638  33.583195  0.386889  0.284062  32.347043
# child        0.539823  2.584071   9.041327  1.460177  1.053097  31.220798

# %%
titanic.groupby('adult_child').count()
# Out:
#              survived  pclass  sex  age  sibsp  parch  fare  embarked  deck
# adult_child
# adult             778     778  778  601    778    778   778       776   184
# child             113     113  113  113    113    113   113       113    19

# %%
titanic.adult_child.value_counts()
# Out:
# adult    778
# child    113
# Name: adult_child, dtype: int64

# %%
titanic.groupby('adult_child')[['survived']].count()
# Out:
#              survived
# adult_child
# adult             778
# child             113

# %%
titanic.groupby(['adult_child', 'sex'])[['survived']].count()
# Out:
#                     survived
# adult_child sex
# adult       female       259
#             male         519
# child       female        55
#             male          58

# %%
m_and_c_first = titanic.groupby(['adult_child', 'sex'])[['survived']].mean()\
.sort_values(by='survived', ascending=False)

# %%
m_and_c_first.plot(kind='bar', figsize=(14,8), fontsize=14)
plt.xlabel("Groups", fontsize=13)
plt.ylabel("Survival Rate", fontsize=13)
plt.title("Titanic Survival Rate by Sex/Age-Group", fontsize=16)
plt.show()

# %%
df1 = titanic.groupby('sex')[['survived','pclass','age','fare']].agg(['sum','mean'])

# %%
df1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby('sex')[['survived','pclass','age','fare']].agg(['sum','mean'])
# Out:
#        survived           pclass                 age                   fare  \
#             sum      mean    sum      mean       sum       mean         sum
# sex
# female      233  0.742038    678  2.159236   7286.00  27.915709  13966.6628
# male        109  0.188908   1379  2.389948  13919.17  30.726645  14727.2865
#
#
#              mean
# sex
# female  44.479818
# male    25.523893

# %%
summer.groupby(['Year', 'Medal']).Medal.sum()
# Out:
# Year  Medal
# 1896  Bronze    BronzeBronzeBronzeBronzeBronzeBronzeBronzeBron...
#       Gold      GoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGo...
#       Silver    SilverSilverSilverSilverSilverSilverSilverSilv...
# 1900  Bronze    BronzeBronzeBronzeBronzeBronzeBronzeBronzeBron...
#       Gold      GoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGo...
#                                       ...
# 2008  Gold      GoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGo...
#       Silver    SilverSilverSilverSilverSilverSilverSilverSilv...
# 2012  Bronze    BronzeBronzeBronzeBronzeBronzeBronzeBronzeBron...
#       Gold      GoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGoldGo...
#       Silver    SilverSilverSilverSilverSilverSilverSilverSilv...
# Name: Medal, Length: 81, dtype: object

# %%
summer.groupby(['Year', 'Medal']).Medal.count()
# Out:
# Year  Medal
# 1896  Bronze     40
#       Gold       64
#       Silver     47
# 1900  Bronze    142
#       Gold      178
#                ...
# 2008  Gold      669
#       Silver    663
# 2012  Bronze    680
#       Gold      636
#       Silver    633
# Name: Medal, Length: 81, dtype: int64

# %% [markdown]
# Advanced Aggregation with agg()

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv", \
                      usecols=["survived","pclass","sex","age","fare"])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
titanic.groupby('sex').agg(['mean','sum','min','max'])[['age']]
# Out:
#               age
#              mean       sum   min   max
# sex
# female  27.915709   7286.00  0.75  63.0
# male    30.726645  13919.17  0.42  80.0

# %%
titanic.groupby('sex').agg({'survived':'mean','fare':'sum','age':'max'})
# Out:
#         survived        fare   age
# sex
# female  0.742038  13966.6628  63.0
# male    0.188908  14727.2865  80.0

# %%
titanic.groupby('sex').agg({'survived':['mean', 'count'],'fare':'sum','age':'max'})
# Out:
#         survived              fare   age
#             mean count         sum   max
# sex
# female  0.742038   314  13966.6628  63.0
# male    0.188908   577  14727.2865  80.0

# %% [markdown]
# GroupBy Aggregation with Relabelling (new in Version .25)

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv', \
                      usecols=["survived","pclass","sex","age","fare"])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
titanic.groupby('sex').mean()
# Out:
#         survived    pclass        age       fare
# sex
# female  0.742038  2.159236  27.915709  44.479818
# male    0.188908  2.389948  30.726645  25.523893

# %%
titanic.groupby('sex').agg(['mean','count','median'])
# Out:
#         survived                 pclass                     age               \
#             mean count median      mean count median       mean count median
# sex
# female  0.742038   314      1  2.159236   314      2  27.915709   261   27.0
# male    0.188908   577      0  2.389948   577      3  30.726645   453   29.0
#
#              fare
#              mean count median
# sex
# female  44.479818   314   23.0
# male    25.523893   577   10.5

# %%
titanic.groupby('sex').agg({'survived':'mean','pclass':'count','fare':'median'})
# Out:
#         survived  pclass  fare
# sex
# female  0.742038     314  23.0
# male    0.188908     577  10.5

# %%
titanic.groupby('sex').agg(survived_rate = ('survived','mean'),\
                           pclass_count = ('pclass','count'),\
                           fare_median = ('fare','median'))
# Out:
#         survived_rate  pclass_count  fare_median
# sex
# female       0.742038           314         23.0
# male         0.188908           577         10.5

# %% [markdown]
# Transformation with transform()

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
titanic["group_survival_rate"] = titanic.groupby(['sex','pclass'])\
.survived.transform('mean')

# %%
titanic.loc[(titanic.sex=='male') & (titanic.pclass==1)]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck  \
# 6           0       1  male  54.0      0      0   51.8625        S    E
# 23          1       1  male  28.0      0      0   35.5000        S    A
# 27          0       1  male  19.0      3      2  263.0000        S    C
# 30          0       1  male  40.0      0      0   27.7208        C  NaN
# 34          0       1  male  28.0      1      0   82.1708        C  NaN
# ..        ...     ...   ...   ...    ...    ...       ...      ...  ...
# 839         1       1  male   NaN      0      0   29.7000        C    C
# 857         1       1  male  51.0      0      0   26.5500        S    E
# 867         0       1  male  31.0      0      0   50.4958        S    A
# 872         0       1  male  33.0      0      0    5.0000        S    B
# 889         1       1  male  26.0      0      0   30.0000        C    C
#
#      group_survival_rate
# 6               0.368852
# 23              0.368852
# ...

# %%
titanic.groupby(['sex','pclass'])[['survived']].transform('mean')
# Out:
#      survived
# 0    0.135447
# 1    0.968085
# 2    0.500000
# 3    0.968085
# 4    0.135447
# ..        ...
# 886  0.157407
# 887  0.968085
# 888  0.500000
# 889  0.368852
# 890  0.135447
#
# [891 rows x 1 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    group_survival_rate
# 0             0.135447
# 1             0.968085
# 2             0.500000
# 3             0.968085
# 4             0.135447

# %%
titanic['outlier'] = abs(titanic['group_survival_rate'])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    group_survival_rate   outlier
# 0             0.135447  0.135447
# 1             0.968085  0.968085
# 2             0.500000  0.500000
# 3             0.968085  0.968085
# 4             0.135447  0.135447

# %%
titanic.loc[titanic.outlier > .85].sample(n=5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 437         1       2  female  24.0      2      3   18.7500        S  NaN
# 750         1       2  female   4.0      1      1   23.0000        S  NaN
# 539         1       1  female  22.0      0      2   49.5000        C    B
# 498         0       1  female  25.0      1      2  151.5500        S    C
# 796         1       1  female  49.0      0      0   25.9292        S    D
#
#      group_survival_rate   outlier
# 437             0.921053  0.921053
# 750             0.921053  0.921053
# 539             0.968085  0.968085
# 498             0.968085  0.968085
# 796             0.968085  0.968085

# %% [markdown]
# Replacing NA values by group-specific Values

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
mean_age = titanic.age.mean()

# %%
mean_age
# Out:
# 29.69911764705882

# %%
titanic.age.fillna(mean_age)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
titanic.sample(n=5)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked deck
# 748         0       1    male  19.0      1      0  53.100        S    D
# 850         0       3    male   4.0      4      2  31.275        S  NaN
# 562         0       2    male  28.0      0      0  13.500        S  NaN
# 272         1       2  female  41.0      0      1  19.500        S  NaN
# 185         0       1    male   NaN      0      0  50.000        S    A

# %%
titanic.groupby(['sex','pclass'])[['age']].agg('mean')
# Out:
#                      age
# sex    pclass
# female 1       34.611765
#        2       28.722973
#        3       21.750000
# male   1       41.281386
#        2       30.740707
#        3       26.507589

# %%
titanic['group_mean_age'] = titanic.groupby(['sex','pclass'])\
[['age']].transform('mean')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    group_mean_age
# 0       26.507589
# 1       34.611765
# 2       21.750000
# 3       34.611765
# 4       26.507589

# %%
titanic.groupby(['sex','pclass'])[['age','group_mean_age']].agg('mean')
# Out:
#                      age  group_mean_age
# sex    pclass
# female 1       34.611765       34.611765
#        2       28.722973       28.722973
#        3       21.750000       21.750000
# male   1       41.281386       41.281386
#        2       30.740707       30.740707
#        3       26.507589       26.507589

# %%
titanic['age'].fillna(titanic.group_mean_age, inplace=True)

# %%
titanic.groupby(['sex','pclass'])[['age','group_mean_age']].agg('mean')
# Out:
#                      age  group_mean_age
# sex    pclass
# female 1       34.611765       34.611765
#        2       28.722973       28.722973
#        3       21.750000       21.750000
# male   1       41.281386       41.281386
#        2       30.740707       30.740707
#        3       26.507589       26.507589

# %%
titanic.loc[:, ['age','group_mean_age', 'sex']].sample(n=5)
# Out:
#            age  group_mean_age     sex
# 487  58.000000       41.281386    male
# 217  42.000000       30.740707    male
# 192  19.000000       21.750000  female
# 717  27.000000       28.722973  female
# 42   26.507589       26.507589    male

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   survived        891 non-null    int64
#  1   pclass          891 non-null    int64
#  2   sex             891 non-null    object
#  3   age             891 non-null    float64
#  4   sibsp           891 non-null    int64
#  5   parch           891 non-null    int64
#  6   fare            891 non-null    float64
#  7   embarked        889 non-null    object
#  8   deck            203 non-null    object
#  9   group_mean_age  891 non-null    float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# Generalizing split-apply-combine with apply()

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv", \
                      usecols=["survived","pclass","sex","age","fare"])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
titanic.groupby('sex').mean()
# Out:
#         survived    pclass        age       fare
# sex
# female  0.742038  2.159236  27.915709  44.479818
# male    0.188908  2.389948  30.726645  25.523893

# %%
female_group = list(titanic.groupby('sex'))[0][1]

# %%
female_group.mean()
# Out:
# survived     0.742038
# pclass       2.159236
# age         27.915709
# fare        44.479818
# dtype: float64

# %%
titanic.groupby('sex').transform('mean').astype('float')
# Out:
#      survived    pclass        age       fare
# 0    0.188908  2.389948  30.726645  25.523893
# 1    0.742038  2.159236  27.915709  44.479818
# 2    0.742038  2.159236  27.915709  44.479818
# 3    0.742038  2.159236  27.915709  44.479818
# 4    0.188908  2.389948  30.726645  25.523893
# ..        ...       ...        ...        ...
# 886  0.188908  2.389948  30.726645  25.523893
# 887  0.742038  2.159236  27.915709  44.479818
# 888  0.742038  2.159236  27.915709  44.479818
# 889  0.188908  2.389948  30.726645  25.523893
# 890  0.188908  2.389948  30.726645  25.523893
#
# [891 rows x 4 columns]

# %%
def group_mean(group):
    return group.mean()

# %%
group_mean(female_group)
# Out:
# survived     0.742038
# pclass       2.159236
# age         27.915709
# fare        44.479818
# dtype: float64

# %%
titanic.groupby('sex').agg(group_mean)
# Out:
#         survived    pclass        age       fare
# sex
# female  0.742038  2.159236  27.915709  44.479818
# male    0.188908  2.389948  30.726645  25.523893

# %%
titanic.groupby('sex').apply(group_mean)
# Out:
#         survived    pclass        age       fare
# sex
# female  0.742038  2.159236  27.915709  44.479818
# male    0.188908  2.389948  30.726645  25.523893

# %%
type(titanic.groupby('sex').apply(group_mean))
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.groupby('sex').mean()
# Out:
#         survived    pclass        age       fare
# sex
# female  0.742038  2.159236  27.915709  44.479818
# male    0.188908  2.389948  30.726645  25.523893

# %%
titanic.nlargest(5, 'age')
# Out:
#      survived  pclass   sex   age     fare
# 630         1       1  male  80.0  30.0000
# 851         0       3  male  74.0   7.7750
# 96          0       1  male  71.0  34.6542
# 493         0       1  male  71.0  49.5042
# 116         0       3  male  70.5   7.7500

# %%
def five_oldest_surv(group):
    return group[group.survived == 1].nlargest(3, 'age')

# %%
titanic.groupby('sex').apply(five_oldest_surv)
# Out:
#             survived  pclass     sex   age     fare
# sex
# female 275         1       1  female  63.0  77.9583
#        483         1       3  female  63.0   9.5875
#        829         1       1  female  62.0  80.0000
# male   630         1       1    male  80.0  30.0000
#        570         1       2    male  62.0  10.5000
#        587         1       1    male  60.0  79.2000

# %%
type(titanic.groupby('sex').apply(five_oldest_surv))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Hierarchical Indexing (MultiIndex) with Groupby

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv', \
                      usecols = ['survived','pclass', 'sex', 'age', 'fare'])

# %%
summary = titanic.groupby(['sex', 'pclass']).mean()

# %%
summary
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.968085  34.611765  106.125798
#        2       0.921053  28.722973   21.970121
#        3       0.500000  21.750000   16.118810
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
#        3       0.135447  26.507589   12.661633

# %%
summary.index
# Out:
# MultiIndex([('female', 1),
#             ('female', 2),
#             ('female', 3),
#             (  'male', 1),
#             (  'male', 2),
#             (  'male', 3)],
#            names=['sex', 'pclass'])

# %%
summary.columns
# Out:
# Index(['survived', 'age', 'fare'], dtype='object')

# %%
summary.loc[('female', 1),:]
# Out:
# survived      0.968085
# age          34.611765
# fare        106.125798
# Name: (female, 1), dtype: float64

# %%
summary.loc[(['male', 'female'], 1),:]
# Out:
#                survived        age        fare
# sex    pclass
# male   1       0.368852  41.281386   67.226127
# female 1       0.968085  34.611765  106.125798

# %%
summary
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.968085  34.611765  106.125798
#        2       0.921053  28.722973   21.970121
#        3       0.500000  21.750000   16.118810
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
#        3       0.135447  26.507589   12.661633

# %%
summary.loc[(['male', 'female'], [1,2]),:]
# Out:
#                survived        age        fare
# sex    pclass
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
# female 1       0.968085  34.611765  106.125798
#        2       0.921053  28.722973   21.970121

# %%
type(titanic.groupby(['sex', 'pclass']).mean())
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic.groupby(['sex', 'pclass']).agg('mean'))
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic.groupby(['sex', 'pclass']).transform('mean'))
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic.groupby(['sex']).age.agg('mean'))
# Out:
# pandas.core.series.Series

# %%
type(titanic.groupby(['sex']).age.transform('mean'))
# Out:
# pandas.core.series.Series

# %%
titanic.groupby(['sex']).age.transform('mean').head()
# Out:
# 0    30.726645
# 1    27.915709
# 2    27.915709
# 3    27.915709
# 4    30.726645
# Name: age, dtype: float64

# %%
titanic.groupby(['sex']).age.agg('mean')
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
summary
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.968085  34.611765  106.125798
#        2       0.921053  28.722973   21.970121
#        3       0.500000  21.750000   16.118810
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
#        3       0.135447  26.507589   12.661633

# %%
summary.loc[('female', [2,3]), ['age','fare']]
# Out:
#                      age       fare
# sex    pclass
# female 2       28.722973  21.970121
#        3       21.750000  16.118810

# %%
summary.swaplevel()
# Out:
#                survived        age        fare
# pclass sex
# 1      female  0.968085  34.611765  106.125798
# 2      female  0.921053  28.722973   21.970121
# 3      female  0.500000  21.750000   16.118810
# 1      male    0.368852  41.281386   67.226127
# 2      male    0.157407  30.740707   19.741782
# 3      male    0.135447  26.507589   12.661633

# %%
summary.swaplevel().sort_index()
# Out:
#                survived        age        fare
# pclass sex
# 1      female  0.968085  34.611765  106.125798
#        male    0.368852  41.281386   67.226127
# 2      female  0.921053  28.722973   21.970121
#        male    0.157407  30.740707   19.741782
# 3      female  0.500000  21.750000   16.118810
#        male    0.135447  26.507589   12.661633

# %%
summary
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.968085  34.611765  106.125798
#        2       0.921053  28.722973   21.970121
#        3       0.500000  21.750000   16.118810
# male   1       0.368852  41.281386   67.226127
#        2       0.157407  30.740707   19.741782
#        3       0.135447  26.507589   12.661633

# %%
summary.reset_index()
# Out:
#       sex  pclass  survived        age        fare
# 0  female       1  0.968085  34.611765  106.125798
# 1  female       2  0.921053  28.722973   21.970121
# 2  female       3  0.500000  21.750000   16.118810
# 3    male       1  0.368852  41.281386   67.226127
# 4    male       2  0.157407  30.740707   19.741782
# 5    male       3  0.135447  26.507589   12.661633

# %% [markdown]
# Stack() and unstack()

# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv')
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
medals_by_country = summer.groupby(['Country', 'Medal'])['Medal'].agg('count')

# %%
medals_by_country.sample(n=5)
# Out:
# Country  Medal
# BEL      Bronze    152
# SRB      Silver      2
# GRE      Bronze     52
# SUD      Silver      1
# GHA      Silver      1
# Name: Medal, dtype: int64

# %%
type(medals_by_country)
# Out:
# pandas.core.series.Series

# %%
medals_by_country.loc['USA']
# Out:
# Medal
# Bronze    1098
# Gold      2235
# Silver    1252
# Name: Medal, dtype: int64

# %%
medals_by_country.shape
# Out:
# (347,)

# %%
medals_by_country.loc[('USA', 'Gold')]
# Out:
# 2235

# %%
medals_by_country.unstack(level=-2)
# Out:
# Country  AFG  AHO  ALG   ANZ   ARG  ARM    AUS   AUT   AZE   BAH  ...    URS  \
# Medal                                                             ...
# Bronze   2.0  NaN  8.0   5.0  91.0  8.0  472.0  44.0  15.0   5.0  ...  584.0
# Gold     NaN  NaN  5.0  20.0  69.0  1.0  312.0  21.0   6.0  13.0  ...  838.0
# Silver   NaN  1.0  2.0   4.0  99.0  2.0  405.0  81.0   5.0   9.0  ...  627.0
#
# Country   URU     USA   UZB  VEN  VIE    YUG  ZAM   ZIM   ZZX
# Medal
# Bronze   30.0  1098.0  10.0  8.0  NaN  118.0  1.0   1.0  10.0
# Gold     44.0  2235.0   5.0  2.0  NaN  143.0  NaN  18.0  23.0
# Silver    2.0  1252.0   5.0  2.0  2.0  174.0  1.0   4.0  15.0
#
# [3 rows x 147 columns]

# %%
medals_by_country = medals_by_country.unstack(level=-1, fill_value=0)

# %%
medals_by_country = medals_by_country.loc[:, ['Gold','Silver','Bronze']]

# %%
medals_by_country.head()
# Out:
# Medal    Gold  Silver  Bronze
# Country
# AFG         0       0       2
# AHO         0       1       0
# ALG         5       2       8
# ANZ        20       4       5
# ARG        69      99      91

# %%
medals_by_country.sort_values(by=['Gold', 'Silver', 'Bronze'], \
                             ascending=[False, False, False], inplace=True)

# %%
medals_by_country.head()
# Out:
# Medal    Gold  Silver  Bronze
# Country
# USA      2235    1252    1098
# URS       838     627     584
# GBR       546     621     553
# ITA       476     416     404
# GER       452     378     475

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
medals_by_country.head().plot(kind='bar', figsize=(12,8), fontsize=12)
plt.xlabel('Country', fontsize=13)
plt.ylabel('Medal per Country', fontsize=16)
plt.legend(fontsize=15)
plt.show()

# %%
medals_by_country
# Out:
# Medal    Gold  Silver  Bronze
# Country
# USA      2235    1252    1098
# URS       838     627     584
# GBR       546     621     553
# ITA       476     416     404
# GER       452     378     475
# ...       ...     ...     ...
# IRQ         0       0       1
# MKD         0       0       1
# MRI         0       0       1
# NIG         0       0       1
# TOG         0       0       1
#
# [147 rows x 3 columns]

# %%
medals_by_country.stack()#.unstack()
# Out:
# Country  Medal
# USA      Gold      2235
#          Silver    1252
#          Bronze    1098
# URS      Gold       838
#          Silver     627
#                    ...
# NIG      Silver       0
#          Bronze       1
# TOG      Gold         0
#          Silver       0
#          Bronze       1
# Length: 441, dtype: int64

# %% [markdown]
# Exercises

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
cars.groupby('origin')[['mpg']].agg('mean')
# Out:
#               mpg
# origin
# europe  27.891429
# japan   30.450633
# usa     20.083534

# %%
mpg_by_year = cars.groupby('model_year')[['mpg']].agg('mean').round(2)

# %%
mpg_by_year.plot()
plt.show()

# %%
mpg_by_orgin_model = cars.groupby(['model_year','origin'])[['mpg']].agg('mean')

# %%
mpg_by_orgin_model.unstack().round(2)
# Out:
#               mpg
# origin     europe  japan    usa
# model_year
# 70          25.20  25.50  15.27
# 71          28.75  29.50  18.10
# 72          22.00  24.20  16.28
# 73          24.00  20.00  15.03
# 74          27.00  29.33  18.33
# 75          24.50  27.50  17.55
# 76          24.25  28.00  19.43
# 77          29.25  27.42  20.72
# 78          24.95  29.69  21.77
# 79          30.45  32.95  23.48
# 80          37.29  35.40  25.91
# 81          31.58  32.96  27.53
# 82          40.00  34.89  29.45

# %%
mpg_by_orgin_model.unstack().round(2).plot()
# Out:
# <AxesSubplot:xlabel='model_year'>

# %%
cars.groupby(['model_year','origin'])[['mpg']].agg(['mean','min','max'])\
.unstack().round(2)
# Out:
#               mpg
#              mean                  min                max
# origin     europe  japan    usa europe japan   usa europe japan   usa
# model_year
# 70          25.20  25.50  15.27   24.0  24.0   9.0   26.0  27.0  22.0
# 71          28.75  29.50  18.10   27.0  25.0  12.0   30.0  35.0  28.0
# 72          22.00  24.20  16.28   18.0  19.0  11.0   26.0  28.0  28.0
# 73          24.00  20.00  15.03   19.0  18.0  11.0   29.0  22.0  23.0
# 74          27.00  29.33  18.33   24.0  24.0  13.0   31.0  32.0  28.0
# 75          24.50  27.50  17.55   22.0  24.0  13.0   29.0  33.0  23.0
# 76          24.25  28.00  19.43   16.5  19.0  13.0   29.5  33.0  29.0
# 77          29.25  27.42  20.72   21.5  21.5  15.0   36.0  33.5  33.5
# 78          24.95  29.69  21.77   16.2  21.1  17.5   43.1  39.4  36.1
# 79          30.45  32.95  23.48   25.4  31.8  15.5   37.3  34.1  35.7
# 80          37.29  35.40  25.91   29.8  23.7  19.1   44.3  46.6  32.1
# ...

# %%
cars.groupby(['model_year','origin'])[['mpg']].agg(['mean','min','max'])\
.unstack().round(2).plot()
# Out:
# <AxesSubplot:xlabel='model_year'>

# %%
cars.groupby(['model_year','origin'])[['mpg']].agg('mean')\
.nlargest(n=2, columns='mpg')
# Out:
#                          mpg
# model_year origin
# 82         europe  40.000000
# 80         europe  37.288889

# %%
cars.nlargest(n=2, columns='mpg')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
#
#      model_year origin                 name
# 322          80  japan            mazda glc
# 329          80  japan  honda civic 1500 gl

# %%
def most_fuel_efficient(group, cols='mpg', num=2):
    return group.nlargest(n=num, columns=cols).loc[:, ['name', cols]]

# %%
cars.groupby(['model_year','origin'])\
.apply(most_fuel_efficient, num=3)
# Out:
#                                                     name   mpg
# model_year origin
# 70         europe 19                vw 1131 deluxe sedan  26.0
#                   23                            bmw 2002  26.0
#                   20                         peugeot 504  25.0
#            japan  18                        datsun pl510  27.0
#                   14               toyota corona mark ii  24.0
# ...                                                  ...   ...
# 82         japan  385                      datsun 310 gx  38.0
#                   376                 mazda glc custom l  37.0
#            usa    378             plymouth horizon miser  38.0
#                   387  oldsmobile cutlass ciera (diesel)  38.0
#                   379                     mercury lynx l  36.0
#
# [114 rows x 2 columns]

# %%
cars.groupby(['model_year','origin'])\
.apply(most_fuel_efficient,cols='horsepower', num=3)
# Out:
#                                         name  horsepower
# model_year origin
# 70         europe 23                bmw 2002       113.0
#                   22                saab 99e        95.0
#                   21             audi 100 ls        90.0
#            japan  14   toyota corona mark ii        95.0
#                   18            datsun pl510        88.0
# ...                                      ...         ...
# 82         japan  380       nissan stanza xe        88.0
#                   381           honda accord        75.0
#            usa    389         ford granada l       112.0
#                   386  buick century limited       110.0
#                   373   ford fairmont futura        92.0
#
# [114 rows x 2 columns]

# %%
most_eff= cars.groupby(['model_year','origin'])\
.apply(most_fuel_efficient,cols='horsepower', num=3)

# %%
most_eff.droplevel(-1)
# Out:
#                                     name  horsepower
# model_year origin
# 70         europe               bmw 2002       113.0
#            europe               saab 99e        95.0
#            europe            audi 100 ls        90.0
#            japan   toyota corona mark ii        95.0
#            japan            datsun pl510        88.0
# ...                                  ...         ...
# 82         japan        nissan stanza xe        88.0
#            japan            honda accord        75.0
#            usa            ford granada l       112.0
#            usa     buick century limited       110.0
#            usa      ford fairmont futura        92.0
#
# [114 rows x 2 columns]

# %%
most_eff.loc[([80,82], 'japan'), :]
# Out:
#                                        name  horsepower
# model_year origin
# 80         japan  333         datsun 280-zx       132.0
#                   334         mazda rx-7 gs       100.0
#                   320  datsun 510 hatchback        92.0
# 82         japan  390      toyota celica gt        96.0
#                   380      nissan stanza xe        88.0
#                   381          honda accord        75.0

# %%
cars['group_mpg'] = cars.groupby(['model_year','origin'])[['mpg']].transform('mean')

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  group_mpg
# 0          70    usa  chevrolet chevelle malibu  15.272727
# 1          70    usa          buick skylark 320  15.272727
# 2          70    usa         plymouth satellite  15.272727
# 3          70    usa              amc rebel sst  15.272727
# 4          70    usa                ford torino  15.272727

# %%
cars['mpg_outlier'] = (cars['mpg'] - cars['group_mpg']).round(2)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  group_mpg  mpg_outlier
# 0          70    usa  chevrolet chevelle malibu  15.272727         2.73
# 1          70    usa          buick skylark 320  15.272727        -0.27
# 2          70    usa         plymouth satellite  15.272727         2.73
# 3          70    usa              amc rebel sst  15.272727         0.73
# 4          70    usa                ford torino  15.272727         1.73

# %%
cars.mpg_outlier.describe()
# Out:
# count    398.000000
# mean       0.000729
# std        4.555381
# min      -11.700000
# 25%       -3.220000
# 50%       -0.885000
# 75%        2.730000
# max       18.150000
# Name: mpg_outlier, dtype: float64

# %%
cars.loc[cars.mpg_outlier.abs() > 10, ['name','mpg','group_mpg', 'mpg_outlier']]
# Out:
#                             name   mpg  group_mpg  mpg_outlier
# 83               dodge colt (sw)  28.0  16.277778        11.72
# 238               dodge colt m/m  33.5  20.722222        12.78
# 244      vw rabbit custom diesel  43.1  24.950000        18.15
# 245                  ford fiesta  36.1  21.772727        14.33
# 295  dodge colt hatchback custom  35.7  23.478261        12.22
# 301             plymouth horizon  34.2  23.478261        10.72
# 302         plymouth horizon tc3  34.5  23.478261        11.02
# 308              pontiac phoenix  33.5  23.478261        10.02
# 322                    mazda glc  46.6  35.400000        11.20
# 334                mazda rx-7 gs  23.7  35.400000       -11.70
# 344               plymouth champ  39.0  27.530769        11.47

# %% [markdown]
# Reshaping DataFrames

# %% [markdown]
# Transposing DataFrames

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.T
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age       22.0     38.0    26.0    35.0  35.0     NaN     54.0     2.0
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
titanic.transpose().T
# Out:
#     survived pclass     sex   age sibsp parch     fare embarked deck
# 0          0      3    male  22.0     1     0     7.25        S  NaN
# 1          1      1  female  38.0     1     0  71.2833        C    C
# 2          1      3  female  26.0     0     0    7.925        S  NaN
# 3          1      1  female  35.0     1     0     53.1        S    C
# 4          0      3    male  35.0     0     0     8.05        S  NaN
# ..       ...    ...     ...   ...   ...   ...      ...      ...  ...
# 886        0      2    male  27.0     0     0     13.0        S  NaN
# 887        1      1  female  19.0     0     0     30.0        S    B
# 888        0      3  female   NaN     1     2    23.45        S  NaN
# 889        1      1    male  26.0     0     0     30.0        C    C
# 890        0      3    male  32.0     0     0     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.groupby(['sex','pclass']).survived.mean().unstack().T
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %% [markdown]
# Pivoting DataFrames with pivot()

# %%
import pandas as pd

# %%
table1 = pd.read_csv("table1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-86f2a2485ef8> in <module>
# ----> 1 table1 = pd.read_csv("table1")
#
# /trials/lab/python/anaconda3-4.10.1/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...
